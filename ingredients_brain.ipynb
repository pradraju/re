# %% [markdown]
# <a href="https://colab.research.google.com/github/pradraju/re/blob/main/ingredients_brain.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install openai google-genai aiohttp pydantic requests
# Out:
# Requirement already satisfied: openai in /usr/local/lib/python3.12/dist-packages (1.106.0)
# Requirement already satisfied: google-genai in /usr/local/lib/python3.12/dist-packages (1.33.0)
# Requirement already satisfied: aiohttp in /usr/local/lib/python3.12/dist-packages (3.12.15)
# Requirement already satisfied: pydantic in /usr/local/lib/python3.12/dist-packages (2.11.7)
# Requirement already satisfied: requests in /usr/local/lib/python3.12/dist-packages (2.32.4)
# Requirement already satisfied: anyio<5,>=3.5.0 in /usr/local/lib/python3.12/dist-packages (from openai) (4.10.0)
# Requirement already satisfied: distro<2,>=1.7.0 in /usr/local/lib/python3.12/dist-packages (from openai) (1.9.0)
# Requirement already satisfied: httpx<1,>=0.23.0 in /usr/local/lib/python3.12/dist-packages (from openai) (0.28.1)
# Requirement already satisfied: jiter<1,>=0.4.0 in /usr/local/lib/python3.12/dist-packages (from openai) (0.10.0)
# Requirement already satisfied: sniffio in /usr/local/lib/python3.12/dist-packages (from openai) (1.3.1)
# Requirement already satisfied: tqdm>4 in /usr/local/lib/python3.12/dist-packages (from openai) (4.67.1)
# Requirement already satisfied: typing-extensions<5,>=4.11 in /usr/local/lib/python3.12/dist-packages (from openai) (4.15.0)
# Requirement already satisfied: google-auth<3.0.0,>=2.14.1 in /usr/local/lib/python3.12/dist-packages (from google-genai) (2.38.0)
# Requirement already satisfied: tenacity<9.2.0,>=8.2.3 in /usr/local/lib/python3.12/dist-packages (from google-genai) (8.5.0)
# Requirement already satisfied: websockets<15.1.0,>=13.0.0 in /usr/local/lib/python3.12/dist-packages (from google-genai) (15.0.1)
# Requirement already satisfied: aiohappyeyeballs>=2.5.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp) (2.6.1)
# Requirement already satisfied: aiosignal>=1.4.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp) (1.4.0)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp) (25.3.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.12/dist-packages (from aiohttp) (1.7.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.12/dist-packages (from aiohttp) (6.6.4)
# Requirement already satisfied: propcache>=0.2.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp) (0.3.2)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp) (1.20.1)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.12/dist-packages (from pydantic) (0.7.0)
# Requirement already satisfied: pydantic-core==2.33.2 in /usr/local/lib/python3.12/dist-packages (from pydantic) (2.33.2)
# Requirement already satisfied: typing-inspection>=0.4.0 in /usr/local/lib/python3.12/dist-packages (from pydantic) (0.4.1)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests) (3.4.3)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests) (2025.8.3)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in /usr/local/lib/python3.12/dist-packages (from google-auth<3.0.0,>=2.14.1->google-genai) (5.5.2)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /usr/local/lib/python3.12/dist-packages (from google-auth<3.0.0,>=2.14.1->google-genai) (0.4.2)
# Requirement already satisfied: rsa<5,>=3.1.4 in /usr/local/lib/python3.12/dist-packages (from google-auth<3.0.0,>=2.14.1->google-genai) (4.9.1)
# Requirement already satisfied: httpcore==1.* in /usr/local/lib/python3.12/dist-packages (from httpx<1,>=0.23.0->openai) (1.0.9)
# Requirement already satisfied: h11>=0.16 in /usr/local/lib/python3.12/dist-packages (from httpcore==1.*->httpx<1,>=0.23.0->openai) (0.16.0)
# Requirement already satisfied: pyasn1<0.7.0,>=0.6.1 in /usr/local/lib/python3.12/dist-packages (from pyasn1-modules>=0.2.1->google-auth<3.0.0,>=2.14.1->google-genai) (0.6.1)
# DeepSeek client initialized successfully.
# ✅ DeepSeek working: Hello from DeepSeek
# Call count: 1

# %%
import json
import asyncio
from typing import List, Tuple, Dict, Any, Optional
from datetime import datetime
import os
from pathlib import Path
from openai import AsyncOpenAI

class DeepSeekService:
    def __init__(self, client=None):
        self.client = client
        self.call_count = 0
        self.feedback_enabled = True

        if self.client:
            print("DeepSeekService initialized with provided client for testing.")
            return

        try:
            from google.colab import userdata
            api_key = userdata.get('DEEPSEEK_API_KEY')
            if not api_key:
                print("DEEPSEEK_API_KEY not found in Colab secrets.")
            else:
                self.client = AsyncOpenAI(
                    api_key=api_key, base_url="https://api.deepseek.com"
                )
                print("DeepSeek client initialized successfully.")
        except Exception as e:
            print(f"Failed to initialize DeepSeek client: {e}")

    async def invoke_async(self, prompt: str) -> str:
        """Async invoke using AsyncOpenAI with DeepSeek base_url."""
        if not self.client:
            raise Exception("Cannot invoke DeepSeek, client not initialized.")

        resp = await self.client.chat.completions.create(
            model="deepseek-chat",
            messages=[{"role": "user", "content": prompt}],
            temperature=0.2,
        )
        self.call_count += 1
        return resp.choices[0].message.content

class OpenAIService:
    def __init__(self, client=None):
        self.client = client
        self.call_count = 0
        self.feedback_enabled = True

        if self.client:
            print("OpenAIService initialized with provided client for testing.")
            return

        try:
            from google.colab import userdata
            api_key = userdata.get('OPENAI_API_KEY')
            if not api_key:
                print("OPENAI_API_KEY not found in Colab secrets.")
            else:
                self.client = AsyncOpenAI(api_key=api_key)
                print("OpenAI client initialized successfully.")
        except Exception as e:
            print(f"Failed to initialize OpenAI client: {e}")

    async def invoke_async(self, prompt: str) -> str:
        """Async invoke using AsyncOpenAI."""
        if not self.client:
            raise Exception("Cannot invoke OpenAI, client not initialized.")

        resp = await self.client.chat.completions.create(
            model="gpt-4o-mini",
            messages=[{"role": "user", "content": prompt}],
            temperature=0.2,
        )
        self.call_count += 1
        return resp.choices[0].message.content

class GeminiService:
    def __init__(self, client=None):
        self.client = client
        self.call_count = 0
        self.feedback_enabled = True

        if self.client:
            print("GeminiService initialized with provided client for testing.")
            return

        try:
            from google.colab import userdata
            api_key = userdata.get('GEMINI_API_KEY')
            if not api_key:
                print("GEMINI_API_KEY not found in Colab secrets.")
                return

            from google import genai
            self.client = genai.Client(api_key=api_key)
            print("Gemini client initialized successfully.")
        except Exception as e:
            print(f"Failed to initialize Gemini client: {e}")
            self.client = None

    async def invoke_async(self, prompt: str) -> str:
        """Async invoke using google-genai client."""
        if not self.client:
            raise Exception("Cannot invoke Gemini, client not initialized.")

        try:
            resp = await self.client.aio.models.generate_content(
                model="gemini-1.5-flash",
                contents=prompt,
            )
            self.call_count += 1
            return getattr(resp, "text", "")
        except Exception as e:
            raise Exception(f"Gemini async invoke failed: {e}")

# Test all services
async def test_services():
    services = {}

    # Test DeepSeek
    try:
        deepseek = DeepSeekService()
        if deepseek.client:
            result = await deepseek.invoke_async("Say 'Hello from DeepSeek'")
            services['deepseek'] = deepseek
            print(f"✅ DeepSeek working: {result}")
    except Exception as e:
        print(f"❌ DeepSeek failed: {e}")

    # Test OpenAI
    try:
        openai = OpenAIService()
        if openai.client:
            result = await openai.invoke_async("Say 'Hello from OpenAI'")
            services['openai'] = openai
            print(f"✅ OpenAI working: {result}")
    except Exception as e:
        print(f"❌ OpenAI failed: {e}")

    # Test Gemini
    try:
        gemini = GeminiService()
        if gemini.client:
            result = await gemini.invoke_async("Say 'Hello from Gemini'")
            services['gemini'] = gemini
            print(f"✅ Gemini working: {result}")
    except Exception as e:
        print(f"❌ Gemini failed: {e}")

    print(f"\nAvailable services: {list(services.keys())}")
    return services

# Run the test
services = await test_services()
# Out:
# DeepSeek client initialized successfully.
# ✅ DeepSeek working: Hello from DeepSeek! 😊
# OpenAI client initialized successfully.
# ✅ OpenAI working: Hello from OpenAI! How can I assist you today?
# Gemini client initialized successfully.
# ✅ Gemini working: Hello from Gemini
#
#
# Available services: ['deepseek', 'openai', 'gemini']

# %%
from openai import OpenAI

class OpenAIService:
    def __init__(self, client=None):
        self.client = client
        self.call_count = 0

        if self.client:
            print("OpenAIService initialized with provided client for testing.")
            return

        try:
            from google.colab import userdata
            api_key = userdata.get('OPENAI_API_KEY')
            if not api_key:
                print("OPENAI_API_KEY not found in Colab secrets.")
            else:
                self.client = OpenAI(api_key=api_key)
                print("OpenAI client initialized successfully.")
        except Exception as e:
            print(f"Failed to initialize OpenAI client: {e}")

    def invoke_openai(self, prompt):
        """Invoke OpenAI API."""
        if not self.client:
            raise Exception("Cannot invoke OpenAI, client not initialized.")

        response = self.client.chat.completions.create(
            model="gpt-4o",  # Using o4-mini-high for coding
            messages=[{"role": "user", "content": prompt}],
            temperature=0.2
        )
        return response.choices[0].message.content

# Test OpenAI
try:
    openai = OpenAIService()

    # Test with a simple prompt
    test_prompt = "Say 'Hello from OpenAI' and nothing else."
    result = openai.invoke_openai(test_prompt)
    print(f"✅ OpenAI working: {result}")

except Exception as e:
    print(f"❌ OpenAI setup failed: {e}")
# Out:
# OpenAI client initialized successfully.
# ✅ OpenAI working: Hello from OpenAI

# %%
# Out:
# Requirement already satisfied: pydantic in /usr/local/lib/python3.11/dist-packages (2.11.7)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.11/dist-packages (from pydantic) (0.7.0)
# Requirement already satisfied: pydantic-core==2.33.2 in /usr/local/lib/python3.11/dist-packages (from pydantic) (2.33.2)
# Requirement already satisfied: typing-extensions>=4.12.2 in /usr/local/lib/python3.11/dist-packages (from pydantic) (4.14.1)
# Requirement already satisfied: typing-inspection>=0.4.0 in /usr/local/lib/python3.11/dist-packages (from pydantic) (0.4.1)
# 🔄 Loading ingredients database...
# ❌ Invalid database entry: 2 validation errors for DatabaseEntry
# id
#   Field required [type=missing, input_value={'parents': [], 'names': ...rue, 'ecodes': ['E100']}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.11/v/missing
# names
#   Input should be a valid string [type=string_type, input_value={'en': ['e100', 'curcumin...: ['e100', '姜黄素']}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.11/v/string_type
# ❌ Invalid database entry: 2 validation errors for DatabaseEntry
# id
#   Field required [type=missing, input_value={'parents': [], 'names': ...rue, 'ecodes': ['E106']}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.11/v/missing
# names
#   Input should be a valid string [type=string_type, input_value={'en': ['e106', 'flavin m..., 'sv': ['e106', 'fmn']}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.11/v/string_type
# ❌ Invalid database entry: 2 validation errors for DatabaseEntry
# id
#   Field required [type=missing, input_value={'parents': [], 'names': ...rue, 'ecodes': ['E101']}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.11/v/missing
# names
#   Input should be a valid string [type=string_type, input_value={'en': ['e101', 'riboflav...min b2', 'laktoflavin']}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.11/v/string_type
# ❌ Invalid database entry: 2 validation errors for DatabaseEntry
# id
#   Field required [type=missing, input_value={'parents': ['en:e101'], ...des': ['E101', 'E101i']}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.11/v/missing
# names
#   Input should be a valid string [type=string_type, input_value={'en': ['e101(i)', 'ribof...e101(i)', 'riboflavin']}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.11/v/string_type
# ❌ Invalid database entry: 2 validation errors for DatabaseEntry
# id
#   Field required [type=missing, input_value={'parents': ['en:e101'], ...es': ['E101', 'E101ii']}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.11/v/missing
# names
#   Input should be a valid string [type=string_type, input_value={'en': ['e101(ii)', 'ribo...iboflavin-5′-fosfat']}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.11/v/string_type
# ❌ Invalid database entry: 2 validation errors for DatabaseEntry
# id
#   Field required [type=missing, input_value={'parents': [], 'names': ...ne, 'ecodes': ['E101a']}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.11/v/missing
# names
#   Input should be a valid string [type=string_type, input_value={'en': ['e101a', 'e101a f... 'e101a food additive']}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.11/v/string_type
# ❌ Invalid database entry: 2 validation errors for DatabaseEntry
# id
#   Field required [type=missing, input_value={'parents': [], 'names': ...rue, 'ecodes': ['E102']}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.11/v/missing
# names
#   Input should be a valid string [type=string_type, input_value={'en': ['e102', 'tartrazi..., 'тартразин']}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.11/v/string_type
# ❌ Invalid database entry: 2 validation errors for DatabaseEntry
# id
#   Field required [type=missing, input_value={'parents': [], 'names': ...rue, 'ecodes': ['E103']}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.11/v/missing
# names
#   Input should be a valid string [type=string_type, input_value={'en': ['e103', 'alkannin...': ['e103', 'alkannin']}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.11/v/string_type
# ❌ Invalid database entry: 2 validation errors for DatabaseEntry
# id
#   Field required [type=missing, input_value={'parents': [], 'names': ...rue, 'ecodes': ['E104']}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.11/v/missing
# names
#   Input should be a valid string [type=string_type, input_value={'en': ['e104', 'quinolin...'kinolingult', 'e 104']}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.11/v/string_type
# ❌ Invalid database entry: 2 validation errors for DatabaseEntry
# id
#   Field required [type=missing, input_value={'parents': [], 'names': ...rue, 'ecodes': ['E105']}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.11/v/missing
# names
#   Input should be a valid string [type=string_type, input_value={'en': ['e105', 'e105 foo..., 'e105 food additive']}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.11/v/string_type
# ❌ Invalid database entry: 2 validation errors for DatabaseEntry
# id
#   Field required [type=missing, input_value={'parents': [], 'names': ...rue, 'ecodes': ['E107']}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.11/v/missing
# names
#   Input should be a valid string [type=string_type, input_value={'en': ['e107', 'yellow 2...sv': ['e107', 'gul 2g']}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.11/v/string_type
# ❌ Invalid database entry: 2 validation errors for DatabaseEntry
# id
#   Field required [type=missing, input_value={'parents': [], 'names': ...rue, 'ecodes': ['E110']}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.11/v/missing
# names
#   Input should be a valid string [type=string_type, input_value={'en': ['e110', 'sunset y...', 'yellow 6', 'e 110']}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.11/v/string_type
# ❌ Invalid database entry: 2 validation errors for DatabaseEntry
# id
#   Field required [type=missing, input_value={'parents': [], 'names': ...rue, 'ecodes': ['E111']}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.11/v/missing
# names
#   Input should be a valid string [type=string_type, input_value={'en': ['e111', 'orange g...htol', 'orange naftol']}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.11/v/string_type
# ❌ Invalid database entry: 2 validation errors for DatabaseEntry
# id
#   Field required [type=missing, input_value={'parents': [], 'names': ...lse, 'ecodes': ['E120']}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.11/v/missing
# names
#   Input should be a valid string [type=string_type, input_value={'en': ['e120', 'cochinea...: ['e120', '胭脂红']}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.11/v/string_type
# ❌ Invalid database entry: 2 validation errors for DatabaseEntry
# id
#   Field required [type=missing, input_value={'parents': [], 'names': ...rue, 'ecodes': ['E121']}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.11/v/missing
# names
#   Input should be a valid string [type=string_type, input_value={'en': ['e121', 'citrus r...'e121', 'citrusröd 2']}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.11/v/string_type
# ❌ Invalid database entry: 2 validation errors for DatabaseEntry
# id
#   Field required [type=missing, input_value={'parents': [], 'names': ...rue, 'ecodes': ['E122']}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.11/v/missing
# names
#   Input should be a valid string [type=string_type, input_value={'en': ['e122', 'azorubin...', 'karmosin', 'e 122']}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.11/v/string_type
# ❌ Invalid database entry: 2 validation errors for DatabaseEntry
# id
#   Field required [type=missing, input_value={'parents': [], 'names': ...rue, 'ecodes': ['E123']}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.11/v/missing
# names
#   Input should be a valid string [type=string_type, input_value={'en': ['e123', 'amaranth...v': ['e123', 'amarant']}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.11/v/string_type
# ❌ Invalid database entry: 2 validation errors for DatabaseEntry
# id
#   Field required [type=missing, input_value={'parents': [], 'names': ...rue, 'ecodes': ['E124']}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.11/v/missing
# names
#   Input should be a valid string [type=string_type, input_value={'en': ['e124', 'ponceau ...d red 7', 'ponceau 4r']}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.11/v/string_type
# ❌ Invalid database entry: 2 validation errors for DatabaseEntry
# id
#   Field required [type=missing, input_value={'parents': [], 'names': ...rue, 'ecodes': ['E125']}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.11/v/missing
# names
#   Input should be a valid string [type=string_type, input_value={'en': ['e125', 'scarlet ..., 'e125 food additive']}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.11/v/string_type
# ❌ Invalid database entry: 2 validation errors for DatabaseEntry
# id
#   Field required [type=missing, input_value={'parents': [], 'names': ...rue, 'ecodes': ['E126']}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.11/v/missing
# names
#   Input should be a valid string [type=string_type, input_value={'en': ['e126', 'ponceau ..., 'e126 food additive']}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.11/v/string_type
# ❌ Invalid database entry: 2 validation errors for DatabaseEntry
# id
#   Field required [type=missing, input_value={'parents': [], 'names': ...rue, 'ecodes': ['E127']}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.11/v/missing
# names
#   Input should be a valid string [type=string_type, input_value={'en': ['e127', 'erythros...: ['e127', '赤藓红']}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.11/v/string_type
# ❌ Invalid database entry: 2 validation errors for DatabaseEntry
# id
#   Field required [type=missing, input_value={'parents': [], 'names': ...rue, 'ecodes': ['E128']}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.11/v/missing
# names
#   Input should be a valid string [type=string_type, input_value={'en': ['e128', 'red 2g']...8', 'röd 2g', 'e 128']}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.11/v/string_type
# ❌ Invalid database entry: 2 validation errors for DatabaseEntry
# id
#   Field required [type=missing, input_value={'parents': [], 'names': ...rue, 'ecodes': ['E129']}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.11/v/missing
# names
#   Input should be a valid string [type=string_type, input_value={'en': ['e129', 'allura r...lurarött ac', 'e 129']}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.11/v/string_type
# ❌ Invalid database entry: 2 validation errors for DatabaseEntry
# id
#   Field required [type=missing, input_value={'parents': [], 'names': ...rue, 'ecodes': ['E130']}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.11/v/missing
# names
#   Input should be a valid string [type=string_type, input_value={'en': ['e130', 'indanthr...trenblå', 'indantren']}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.11/v/string_type
# ❌ Invalid database entry: 2 validation errors for DatabaseEntry
# id
#   Field required [type=missing, input_value={'parents': [], 'names': ...rue, 'ecodes': ['E131']}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.11/v/missing
# names
#   Input should be a valid string [type=string_type, input_value={'en': ['e131', 'patent b... ['e131', '專利藍v']}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.11/v/string_type
# ❌ Invalid database entry: 2 validation errors for DatabaseEntry
# id
#   Field required [type=missing, input_value={'parents': [], 'names': ...rue, 'ecodes': ['E132']}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.11/v/missing
# names
#   Input should be a valid string [type=string_type, input_value={'en': ['e132', 'indigoti...gotin', 'indigokarmin']}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.11/v/string_type
# ❌ Invalid database entry: 2 validation errors for DatabaseEntry
# id
#   Field required [type=missing, input_value={'parents': [], 'names': ...rue, 'ecodes': ['E133']}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.11/v/missing
# names
#   Input should be a valid string [type=string_type, input_value={'en': ['e133', 'brillian...товий синій']}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.11/v/string_type
# ❌ Invalid database entry: 2 validation errors for DatabaseEntry
# id
#   Field required [type=missing, input_value={'parents': [], 'names': ...rue, 'ecodes': ['E140']}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.11/v/missing
# names
#   Input should be a valid string [type=string_type, input_value={'en': ['e140', 'chloroph...ler och klorofylliner']}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.11/v/string_type
# ❌ Invalid database entry: 2 validation errors for DatabaseEntry
# id
#   Field required [type=missing, input_value={'parents': ['en:e140'], ...des': ['E140', 'E140i']}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.11/v/missing
# names
#   Input should be a valid string [type=string_type, input_value={'en': ['e140(i)', 'chlor...'e140(i)', '叶绿素']}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.11/v/string_type
# ❌ Invalid database entry: 2 validation errors for DatabaseEntry
# id
#   Field required [type=missing, input_value={'parents': ['en:e140'], ...es': ['E140', 'E140ii']}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.11/v/missing
# names
#   Input should be a valid string [type=string_type, input_value={'en': ['e140(ii)', 'chlo..., 'natriumklorofyllin']}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.11/v/string_type
# ❌ Invalid database entry: 2 validation errors for DatabaseEntry
# id
#   Field required [type=missing, input_value={'parents': [], 'names': ...rue, 'ecodes': ['E141']}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.11/v/missing
# names
#   Input should be a valid string [type=string_type, input_value={'en': ['e141', 'copper c..., 'e141 food additive']}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.11/v/string_type
# ❌ Invalid database entry: 2 validation errors for DatabaseEntry
# id
#   Field required [type=missing, input_value={'parents': ['en:e141'], ...des': ['E141', 'E141i']}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.11/v/missing
# names
#   Input should be a valid string [type=string_type, input_value={'en': ['e141(i)', 'coppe...lorofyllkopparkomplex']}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.11/v/string_type
# ❌ Invalid database entry: 2 validation errors for DatabaseEntry
# id
#   Field required [type=missing, input_value={'parents': ['en:e141'], ...es': ['E141', 'E141ii']}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.11/v/missing
# names
#   Input should be a valid string [type=string_type, input_value={'en': ['e141(ii)', 'copp...riumkopparklorofyllin']}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.11/v/string_type
# ❌ Invalid database entry: 2 validation errors for DatabaseEntry
# id
#   Field required [type=missing, input_value={'parents': [], 'names': ...rue, 'ecodes': ['E142']}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.11/v/missing
# names
#   Input should be a valid string [type=string_type, input_value={'en': ['e142', 'green s'...2', 'зелений s']}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.11/v/string_type
# ❌ Invalid database entry: 2 validation errors for DatabaseEntry
# id
#   Field required [type=missing, input_value={'parents': [], 'names': ...rue, 'ecodes': ['E143']}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.11/v/missing
# names
#   Input should be a valid string [type=string_type, input_value={'en': ['e143', 'fast gre..., 'e143 food additive']}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.11/v/string_type
# ❌ Invalid database entry: 2 validation errors for DatabaseEntry
# id
#   Field required [type=missing, input_value={'parents': [], 'names': ...rue, 'ecodes': ['E150']}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.11/v/missing
# names
#   Input should be a valid string [type=string_type, input_value={'en': ['e150', 'caramel'...zh': ['e150', '焦糖']}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.11/v/string_type
# ❌ Invalid database entry: 2 validation errors for DatabaseEntry
# id
#   Field required [type=missing, input_value={'parents': [], 'names': ...des': ['E150a', 'E150']}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.11/v/missing
# names
#   Input should be a valid string [type=string_type, input_value={'en': ['e150a', 'plain c...e150a', '焦糖色素']}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.11/v/string_type
# ❌ Invalid database entry: 2 validation errors for DatabaseEntry
# id
#   Field required [type=missing, input_value={'parents': [], 'names': ...ue, 'ecodes': ['E150b']}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.11/v/missing
# names
#   Input should be a valid string [type=string_type, input_value={'en': ['e150b', 'caustic...austiksulfitprocessen']}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.11/v/string_type
# ❌ Invalid database entry: 2 validation errors for DatabaseEntry
# id
#   Field required [type=missing, input_value={'parents': [], 'names': ...ue, 'ecodes': ['E150c']}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.11/v/missing
# names
#   Input should be a valid string [type=string_type, input_value={'en': ['e150c', 'ammonia...', 'ammoniakprocessen']}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.11/v/string_type
# ❌ Invalid database entry: 2 validation errors for DatabaseEntry
# id
#   Field required [type=missing, input_value={'parents': [], 'names': ...ue, 'ecodes': ['E150d']}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.11/v/missing
# names
#   Input should be a valid string [type=string_type, input_value={'en': ['e150d', 'sulphit...lfit amonyak karamel']}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.11/v/string_type
# ❌ Invalid database entry: 2 validation errors for DatabaseEntry
# id
#   Field required [type=missing, input_value={'parents': [], 'names': ...rue, 'ecodes': ['E151']}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.11/v/missing
# names
#   Input should be a valid string [type=string_type, input_value={'en': ['e151', 'brillian...', 'svart pn', 'e 151']}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.11/v/string_type
# ❌ Invalid database entry: 2 validation errors for DatabaseEntry
# id
#   Field required [type=missing, input_value={'parents': [], 'names': ...rue, 'ecodes': ['E152']}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.11/v/missing
# names
#   Input should be a valid string [type=string_type, input_value={'en': ['e152', 'black 79...v': ['e152', 'kimrök']}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.11/v/string_type
# ❌ Invalid database entry: 2 validation errors for DatabaseEntry
# id
#   Field required [type=missing, input_value={'parents': [], 'names': ...rue, 'ecodes': ['E153']}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.11/v/missing
# names
#   Input should be a valid string [type=string_type, input_value={'en': ['e153', 'vegetabl...', 'vegetabiliskt kol']}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.11/v/string_type
# ❌ Invalid database entry: 2 validation errors for DatabaseEntry
# id
#   Field required [type=missing, input_value={'parents': [], 'names': ...rue, 'ecodes': ['E154']}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.11/v/missing
# names
#   Input should be a valid string [type=string_type, input_value={'en': ['e154', 'brown fk...v': ['e154', 'brun fk']}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.11/v/string_type
# ❌ Invalid database entry: 2 validation errors for DatabaseEntry
# id
#   Field required [type=missing, input_value={'parents': [], 'names': ...rue, 'ecodes': ['E155']}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.11/v/missing
# names
#   Input should be a valid string [type=string_type, input_value={'en': ['e155', 'brown ht...5', 'brun ht', 'e 155']}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.11/v/string_type
# ❌ Invalid database entry: 2 validation errors for DatabaseEntry
# id
#   Field required [type=missing, input_value={'parents': [], 'names': ...'E159', 'E152', 'E153']}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.11/v/missing
# names
#   Input should be a valid string [type=string_type, input_value={'en': ['e15x', 'e15x foo..., 'e15x food additive']}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.11/v/string_type
# ❌ Invalid database entry: 2 validation errors for DatabaseEntry
# id
#   Field required [type=missing, input_value={'parents': [], 'names': ...lse, 'ecodes': ['E160']}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.11/v/missing
# names
#   Input should be a valid string [type=string_type, input_value={'en': ['e160', 'caroteno..., 'e160 food additive']}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.11/v/string_type
# ❌ Invalid database entry: 2 validation errors for DatabaseEntry
# id
#   Field required [type=missing, input_value={'parents': [], 'names': ...des': ['E160a', 'E160']}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.11/v/missing
# names
#   Input should be a valid string [type=string_type, input_value={'en': ['e160a', 'caroten...karoten', 'karotenler']}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.11/v/string_type
# ❌ Invalid database entry: 2 validation errors for DatabaseEntry
# id
#   Field required [type=missing, input_value={'parents': ['en:e160a'],...se, 'ecodes': ['E160a']}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.11/v/missing
# names
#   Input should be a valid string [type=string_type, input_value={'en': ['e160a(i)', 'beta...60a(i)', 'betakaroten']}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.11/v/string_type
# ❌ Invalid database entry: 2 validation errors for DatabaseEntry
# id
#   Field required [type=missing, input_value={'parents': ['en:e160a'],...ue, 'ecodes': ['E160a']}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.11/v/missing
# names
#   Input should be a valid string [type=string_type, input_value={'en': ['e160a(ii)', 'pla...rotener från växter']}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.11/v/string_type
# ❌ Invalid database entry: 2 validation errors for DatabaseEntry
# id
#   Field required [type=missing, input_value={'parents': ['en:e160a'],...ue, 'ecodes': ['E160a']}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.11/v/missing
# names
#   Input should be a valid string [type=string_type, input_value={'en': ['e160a(iii)', 'be...n blakeslea trispora']}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.11/v/string_type
# ❌ Invalid database entry: 2 validation errors for DatabaseEntry
# id
#   Field required [type=missing, input_value={'parents': ['en:e160a'],...ue, 'ecodes': ['E160a']}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.11/v/missing
# names
#   Input should be a valid string [type=string_type, input_value={'en': ['e160a(iv)', 'alg...karotener från alger']}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.11/v/string_type
# ❌ Invalid database entry: 2 validation errors for DatabaseEntry
# id
#   Field required [type=missing, input_value={'parents': [], 'names': ...ue, 'ecodes': ['E160b']}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.11/v/missing
# names
#   Input should be a valid string [type=string_type, input_value={'en': ['e160b', 'annatto...e160b', '胭脂樹紅']}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.11/v/string_type
# ❌ Invalid database entry: 2 validation errors for DatabaseEntry
# id
#   Field required [type=missing, input_value={'parents': ['en:e160b'],...ne, 'ecodes': ['E160b']}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.11/v/missing
# names
#   Input should be a valid string [type=string_type, input_value={'en': ['e160b(i)', 'anna...n'], 'xx': ['e160b(i)']}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.11/v/string_type
# ❌ Invalid database entry: 2 validation errors for DatabaseEntry
# id
#   Field required [type=missing, input_value={'parents': ['en:e160b'],...ne, 'ecodes': ['E160b']}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.11/v/missing
# names
#   Input should be a valid string [type=string_type, input_value={'en': ['e160b(ii)', 'ann..., 'norbixine de rocou']}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.11/v/string_type
# ❌ Invalid database entry: 2 validation errors for DatabaseEntry
# id
#   Field required [type=missing, input_value={'parents': [], 'names': ...ue, 'ecodes': ['E160c']}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.11/v/missing
# names
#   Input should be a valid string [type=string_type, input_value={'en': ['e160c', 'paprika..., 'paprika ekstraktı']}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.11/v/string_type
# ❌ Invalid database entry: 2 validation errors for DatabaseEntry
# id
#   Field required [type=missing, input_value={'parents': [], 'names': ...des': ['E160d', 'E160']}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.11/v/missing
# names
#   Input should be a valid string [type=string_type, input_value={'en': ['e160d', 'lycopen...', 'e 160 d', 'e 160d']}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.11/v/string_type
# ❌ Invalid database entry: 2 validation errors for DatabaseEntry
# id
#   Field required [type=missing, input_value={'parents': [], 'names': ...ue, 'ecodes': ['E160E']}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.11/v/missing
# names
#   Input should be a valid string [type=string_type, input_value={'en': ['e160e', 'beta-ap...'-karotenal", 'e 160e']}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.11/v/string_type
# ❌ Invalid database entry: 2 validation errors for DatabaseEntry
# id
#   Field required [type=missing, input_value={'parents': [], 'names': ...ue, 'ecodes': ['E160f']}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.11/v/missing
# names
#   Input should be a valid string [type=string_type, input_value={'en': ['e160f', "ethyl e...8'-胡萝卜酸乙酯"]}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.11/v/string_type
# ❌ Invalid database entry: 2 validation errors for DatabaseEntry
# id
#   Field required [type=missing, input_value={'parents': [], 'names': ...rue, 'ecodes': ['E161']}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.11/v/missing
# names
#   Input should be a valid string [type=string_type, input_value={'en': ['e161', 'xanthoph...['e161', 'xantofyller']}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.11/v/string_type
# ❌ Invalid database entry: 2 validation errors for DatabaseEntry
# id
#   Field required [type=missing, input_value={'parents': [], 'names': ...ue, 'ecodes': ['E161a']}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.11/v/missing
# names
#   Input should be a valid string [type=string_type, input_value={'en': ['e161a', 'flavoxa...'e161a', 'flavoxantin']}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.11/v/string_type
# ❌ Invalid database entry: 2 validation errors for DatabaseEntry
# id
#   Field required [type=missing, input_value={'parents': [], 'names': ...ue, 'ecodes': ['E161b']}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.11/v/missing
# names
#   Input should be a valid string [type=string_type, input_value={'en': ['e161b', 'lutein'... ['e161b', '葉黃素']}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.11/v/string_type
# ❌ Invalid database entry: 2 validation errors for DatabaseEntry
# id
#   Field required [type=missing, input_value={'parents': [], 'names': ...ue, 'ecodes': ['E161c']}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.11/v/missing
# names
#   Input should be a valid string [type=string_type, input_value={'en': ['e161c', 'cryptoa... ['e161c', '隐黄质']}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.11/v/string_type
# ❌ Invalid database entry: 2 validation errors for DatabaseEntry
# id
#   Field required [type=missing, input_value={'parents': [], 'names': ...ue, 'ecodes': ['E161d']}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.11/v/missing
# names
#   Input should be a valid string [type=string_type, input_value={'en': ['e161d', 'rubixan...['e161d', 'rubixantin']}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.11/v/string_type
# ❌ Invalid database entry: 2 validation errors for DatabaseEntry
# id
#   Field required [type=missing, input_value={'parents': [], 'names': ...ue, 'ecodes': ['E161E']}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.11/v/missing
# names
#   Input should be a valid string [type=string_type, input_value={'en': ['e161e', 'violaxa... ['e161e', '紫黄质']}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.11/v/string_type
# ❌ Invalid database entry: 2 validation errors for DatabaseEntry
# id
#   Field required [type=missing, input_value={'parents': [], 'names': ...ue, 'ecodes': ['E161f']}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.11/v/missing
# names
#   Input should be a valid string [type=string_type, input_value={'en': ['e161f', 'rhodoxa... ['e161f', '红黄素']}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.11/v/string_type
# ❌ Invalid database entry: 2 validation errors for DatabaseEntry
# id
#   Field required [type=missing, input_value={'parents': [], 'names': ...ue, 'ecodes': ['E161g']}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.11/v/missing
# names
#   Input should be a valid string [type=string_type, input_value={'en': ['e161g', 'canthax...'e161g', 'kantaxantin']}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.11/v/string_type
# ❌ Invalid database entry: 2 validation errors for DatabaseEntry
# id
#   Field required [type=missing, input_value={'parents': [], 'names': ...ue, 'ecodes': ['E161h']}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.11/v/missing
# names
#   Input should be a valid string [type=string_type, input_value={'en': ['e161h', 'zeaxant...e161h', '玉米黄质']}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.11/v/string_type
# ❌ Invalid database entry: 2 validation errors for DatabaseEntry
# id
#   Field required [type=missing, input_value={'parents': [], 'names': ...des': ['E161', 'E161i']}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.11/v/missing
# names
#   Input should be a valid string [type=string_type, input_value={'en': ['e161i', 'citrana...e161i', '柑橘黄质']}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.11/v/string_type
# ❌ Invalid database entry: 2 validation errors for DatabaseEntry
# id
#   Field required [type=missing, input_value={'parents': [], 'names': ...des': ['E161', 'E161j']}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.11/v/missing
# names
#   Input should be a valid string [type=string_type, input_value={'en': ['e161j', 'astaxan... ['e161j', '虾青素']}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.11/v/string_type
# ❌ Invalid database entry: 2 validation errors for DatabaseEntry
# id
#   Field required [type=missing, input_value={'parents': [], 'names': ...rue, 'ecodes': ['E162']}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.11/v/missing
# names
#   Input should be a valid string [type=string_type, input_value={'en': ['e162', 'beetroot...dbetsrött', 'betanin']}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.11/v/string_type
# ❌ Invalid database entry: 2 validation errors for DatabaseEntry
# id
#   Field required [type=missing, input_value={'parents': [], 'names': ...rue, 'ecodes': ['E163']}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.11/v/missing
# names
#   Input should be a valid string [type=string_type, input_value={'en': ['e163', 'anthocya...'e163', '花色素苷']}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.11/v/string_type
# ❌ Invalid database entry: 2 validation errors for DatabaseEntry
# id
#   Field required [type=missing, input_value={'parents': [], 'names': ...ue, 'ecodes': ['E163a']}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.11/v/missing
# names
#   Input should be a valid string [type=string_type, input_value={'en': ['e163a', 'cyanidi... ['e163a', '花青素']}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.11/v/string_type
# ❌ Invalid database entry: 2 validation errors for DatabaseEntry
# id
#   Field required [type=missing, input_value={'parents': [], 'names': ...ue, 'ecodes': ['E163b']}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.11/v/missing
# names
#   Input should be a valid string [type=string_type, input_value={'en': ['e163b', 'delphin...'e163b', 'delphinidin']}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.11/v/string_type
# ❌ Invalid database entry: 2 validation errors for DatabaseEntry
# id
#   Field required [type=missing, input_value={'parents': [], 'names': ...ue, 'ecodes': ['E163c']}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.11/v/missing
# names
#   Input should be a valid string [type=string_type, input_value={'en': ['e163c', 'malvidi...: ['e163c', 'malvidin']}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.11/v/string_type
# ❌ Invalid database entry: 2 validation errors for DatabaseEntry
# id
#   Field required [type=missing, input_value={'parents': [], 'names': ...ue, 'ecodes': ['E163d']}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.11/v/missing
# names
#   Input should be a valid string [type=string_type, input_value={'en': ['e163d', 'pelargo...e163d', '飞燕草素']}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.11/v/string_type
# ❌ Invalid database entry: 2 validation errors for DatabaseEntry
# id
#   Field required [type=missing, input_value={'parents': [], 'names': ...ue, 'ecodes': ['E163E']}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.11/v/missing
# names
#   Input should be a valid string [type=string_type, input_value={'en': ['e163e', 'peonidi... ['e163e', '芍药苷']}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.11/v/string_type
# ❌ Invalid database entry: 2 validation errors for DatabaseEntry
# id
#   Field required [type=missing, input_value={'parents': [], 'names': ...ue, 'ecodes': ['E163f']}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.11/v/missing
# names
#   Input should be a valid string [type=string_type, input_value={'en': ['e163f', 'petunid... ['e163f', 'petunidin']}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.11/v/string_type
# ❌ Invalid database entry: 2 validation errors for DatabaseEntry
# id
#   Field required [type=missing, input_value={'parents': [], 'names': ...rue, 'ecodes': ['E164']}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.11/v/missing
# names
#   Input should be a valid string [type=string_type, input_value={'en': ['e164', 'saffron'...: ['e164', '番紅花']}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.11/v/string_type
# ❌ Invalid database entry: 2 validation errors for DatabaseEntry
# id
#   Field required [type=missing, input_value={'parents': [], 'names': ...rue, 'ecodes': ['E165']}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.11/v/missing
# names
#   Input should be a valid string [type=string_type, input_value={'en': ['e165', 'gardenia...e165', 'gardenia blå']}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.11/v/string_type
# ❌ Invalid database entry: 2 validation errors for DatabaseEntry
# id
#   Field required [type=missing, input_value={'parents': [], 'names': ...rue, 'ecodes': ['E166']}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.11/v/missing
# names
#   Input should be a valid string [type=string_type, input_value={'en': ['e166', 'sandalwo... ['e166', 'sandelträ']}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.11/v/string_type
# ❌ Invalid database entry: 2 validation errors for DatabaseEntry
# id
#   Field required [type=missing, input_value={'parents': [], 'names': ...one, 'ecodes': ['E170']}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.11/v/missing
# names
#   Input should be a valid string [type=string_type, input_value={'en': ['e170', 'calcium ...: ['e170', '碳酸钙']}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.11/v/string_type
# ❌ Invalid database entry: 2 validation errors for DatabaseEntry
# id
#   Field required [type=missing, input_value={'parents': ['en:e170'], ...des': ['E170', 'E170i']}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.11/v/missing
# names
#   Input should be a valid string [type=string_type, input_value={'en': ['e170(i)', 'calci...'e170(i)', '碳酸鈣']}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.11/v/string_type
# ❌ Invalid database entry: 2 validation errors for DatabaseEntry
# id
#   Field required [type=missing, input_value={'parents': ['en:e170'], ...e, 'ecodes': ['E170ii']}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.11/v/missing
# names
#   Input should be a valid string [type=string_type, input_value={'en': ['e170(ii)', 'calc...0(ii)', '碳酸氫鈣']}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.11/v/string_type
# ❌ Invalid database entry: 2 validation errors for DatabaseEntry
# id
#   Field required [type=missing, input_value={'parents': [], 'names': ...rue, 'ecodes': ['E171']}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.11/v/missing
# names
#   Input should be a valid string [type=string_type, input_value={'en': ['e171', 'titanium...'e171', '二氧化鈦']}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.11/v/string_type
# ❌ Invalid database entry: 2 validation errors for DatabaseEntry
# id
#   Field required [type=missing, input_value={'parents': [], 'names': ...rue, 'ecodes': ['E172']}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.11/v/missing
# names
#   Input should be a valid string [type=string_type, input_value={'en': ['e172', 'iron oxi...oxider', 'järnoxider']}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.11/v/string_type
# ❌ Invalid database entry: 2 validation errors for DatabaseEntry
# id
#   Field required [type=missing, input_value={'parents': ['en:e172'], ...des': ['E172', 'E172i']}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.11/v/missing
# names
#   Input should be a valid string [type=string_type, input_value={'en': ['e172(i)', 'black...i)', 'svart järnoxid']}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.11/v/string_type
# ❌ Invalid database entry: 2 validation errors for DatabaseEntry
# id
#   Field required [type=missing, input_value={'parents': ['en:e172'], ...es': ['E172', 'E172ii']}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.11/v/missing
# names
#   Input should be a valid string [type=string_type, input_value={'en': ['e172(ii)', 'red ...i)', '红色氧化铁']}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.11/v/string_type
# ❌ Invalid database entry: 2 validation errors for DatabaseEntry
# id
#   Field required [type=missing, input_value={'parents': ['en:e172'], ...s': ['E172', 'E172iii']}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.11/v/missing
# names
#   Input should be a valid string [type=string_type, input_value={'en': ['e172(iii)', 'yel...iii)', 'gul järnoxid']}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.11/v/string_type
# ❌ Invalid database entry: 2 validation errors for DatabaseEntry
# id
#   Field required [type=missing, input_value={'parents': [], 'names': ...rue, 'ecodes': ['E173']}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.11/v/missing
# names
#   Input should be a valid string [type=string_type, input_value={'en': ['e173', 'aluminiu...: ['e173', 'aluminium']}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.11/v/string_type
# ❌ Invalid database entry: 2 validation errors for DatabaseEntry
# id
#   Field required [type=missing, input_value={'parents': [], 'names': ...rue, 'ecodes': ['E174']}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.11/v/missing
# names
#   Input should be a valid string [type=string_type, input_value={'en': ['e174', 'silver',...sv': ['e174', 'silver']}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.11/v/string_type
# ❌ Invalid database entry: 2 validation errors for DatabaseEntry
# id
#   Field required [type=missing, input_value={'parents': [], 'names': ...rue, 'ecodes': ['E175']}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.11/v/missing
# names
#   Input should be a valid string [type=string_type, input_value={'en': ['e175', 'gold', '...ld', 'pigment metal 3']}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.11/v/string_type
# ❌ Invalid database entry: 2 validation errors for DatabaseEntry
# id
#   Field required [type=missing, input_value={'parents': [], 'names': ...rue, 'ecodes': ['E180']}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.11/v/missing
# names
#   Input should be a valid string [type=string_type, input_value={'en': ['e180', 'litholru...rubinpigment', 'e 180']}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.11/v/string_type
# ❌ Invalid database entry: 2 validation errors for DatabaseEntry
# id
#   Field required [type=missing, input_value={'parents': [], 'names': ...rue, 'ecodes': ['E181']}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.11/v/missing
# names
#   Input should be a valid string [type=string_type, input_value={'en': ['e181', 'tannin']...: ['e181', '丹宁酸']}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.11/v/string_type
# ❌ Invalid database entry: 2 validation errors for DatabaseEntry
# id
#   Field required [type=missing, input_value={'parents': [], 'names': ...rue, 'ecodes': ['E182']}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.11/v/missing
# names
#   Input should be a valid string [type=string_type, input_value={'en': ['e182', 'orcein']...h': ['e182', '奥cein']}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.11/v/string_type
# ❌ Invalid database entry: 2 validation errors for DatabaseEntry
# id
#   Field required [type=missing, input_value={'parents': [], 'names': ...rue, 'ecodes': ['E200']}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.11/v/missing
# names
#   Input should be a valid string [type=string_type, input_value={'en': ['e200', 'sorbic a...: ['e200', '山梨酸']}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.11/v/string_type
# ❌ Invalid database entry: 2 validation errors for DatabaseEntry
# id
#   Field required [type=missing, input_value={'parents': [], 'names': ...rue, 'ecodes': ['E201']}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.11/v/missing
# names
#   Input should be a valid string [type=string_type, input_value={'en': ['e201', 'sodium s...hexa-2\\', '4-dienoat']}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.11/v/string_type
# ❌ Invalid database entry: 2 validation errors for DatabaseEntry
# id
#   Field required [type=missing, input_value={'parents': [], 'names': ...rue, 'ecodes': ['E202']}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.11/v/missing
# names
#   Input should be a valid string [type=string_type, input_value={'en': ['e202', 'potassiu...'e202', '山梨酸钾']}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.11/v/string_type
# ❌ Invalid database entry: 2 validation errors for DatabaseEntry
# id
#   Field required [type=missing, input_value={'parents': [], 'names': ...rue, 'ecodes': ['E203']}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.11/v/missing
# names
#   Input should be a valid string [type=string_type, input_value={'en': ['e203', 'calcium ...'e203', 'canxi sorbat']}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.11/v/string_type
# ...
#     For further information visit https://errors.pydantic.dev/2.11/v/string_type
# ❌ Invalid database entry: 2 validation errors for DatabaseEntry
# id
#   Field required [type=missing, input_value={'parents': [], 'names': ...ue, 'ecodes': ['E1414']}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.11/v/missing
# names
#   Input should be a valid string [type=string_type, input_value={'en': ['e1414', 'acetyla...at distärkelsefosfat']}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.11/v/string_type
# ❌ Invalid database entry: 2 validation errors for DatabaseEntry
# id
#   Field required [type=missing, input_value={'parents': [], 'names': ...ue, 'ecodes': ['E1420']}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.11/v/missing
# names
#   Input should be a valid string [type=string_type, input_value={'en': ['e1420', 'acetyla...0', 'stärkelseacetat']}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.11/v/string_type
# ❌ Invalid database entry: 2 validation errors for DatabaseEntry
# id
#   Field required [type=missing, input_value={'parents': [], 'names': ...ue, 'ecodes': ['E1421']}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.11/v/missing
# names
#   Input should be a valid string [type=string_type, input_value={'en': ['e1421', 'acetyla...ierat med vinylacetat']}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.11/v/string_type
# ❌ Invalid database entry: 2 validation errors for DatabaseEntry
# id
#   Field required [type=missing, input_value={'parents': [], 'names': ...ue, 'ecodes': ['E1422']}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.11/v/missing
# names
#   Input should be a valid string [type=string_type, input_value={'en': ['e1422', 'acetyla...at distärkelseadipat']}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.11/v/string_type
# ❌ Invalid database entry: 2 validation errors for DatabaseEntry
# id
#   Field required [type=missing, input_value={'parents': [], 'names': ...ue, 'ecodes': ['E1423']}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.11/v/missing
# names
#   Input should be a valid string [type=string_type, input_value={'en': ['e1423', 'acetyla... distärkelseglycerol']}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.11/v/string_type
# ❌ Invalid database entry: 2 validation errors for DatabaseEntry
# id
#   Field required [type=missing, input_value={'parents': [], 'names': ...ue, 'ecodes': ['E1430']}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.11/v/missing
# names
#   Input should be a valid string [type=string_type, input_value={'en': ['e1430', 'distarc...'distärkelseglycerin']}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.11/v/string_type
# ❌ Invalid database entry: 2 validation errors for DatabaseEntry
# id
#   Field required [type=missing, input_value={'parents': [], 'names': ...ue, 'ecodes': ['E1440']}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.11/v/missing
# names
#   Input should be a valid string [type=string_type, input_value={'en': ['e1440', 'hydroxy...droxipropylstärkelse']}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.11/v/string_type
# ❌ Invalid database entry: 2 validation errors for DatabaseEntry
# id
#   Field required [type=missing, input_value={'parents': [], 'names': ...ue, 'ecodes': ['E1441']}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.11/v/missing
# names
#   Input should be a valid string [type=string_type, input_value={'en': ['e1441', 'hydroxy...ropil distar gliserol']}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.11/v/string_type
# ❌ Invalid database entry: 2 validation errors for DatabaseEntry
# id
#   Field required [type=missing, input_value={'parents': [], 'names': ...ue, 'ecodes': ['E1442']}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.11/v/missing
# names
#   Input should be a valid string [type=string_type, input_value={'en': ['e1442', 'hydroxy...pyldistärkelsefosfat']}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.11/v/string_type
# ❌ Invalid database entry: 2 validation errors for DatabaseEntry
# id
#   Field required [type=missing, input_value={'parents': [], 'names': ...ue, 'ecodes': ['E1443']}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.11/v/missing
# names
#   Input should be a valid string [type=string_type, input_value={'en': ['e1443', 'hydroxy...pil distarş gliserol']}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.11/v/string_type
# ❌ Invalid database entry: 2 validation errors for DatabaseEntry
# id
#   Field required [type=missing, input_value={'parents': [], 'names': ...ue, 'ecodes': ['E1450']}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.11/v/missing
# names
#   Input should be a valid string [type=string_type, input_value={'en': ['e1450', 'starch ...nylsuccinatstärkelse']}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.11/v/string_type
# ❌ Invalid database entry: 2 validation errors for DatabaseEntry
# id
#   Field required [type=missing, input_value={'parents': [], 'names': ...ue, 'ecodes': ['E1451']}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.11/v/missing
# names
#   Input should be a valid string [type=string_type, input_value={'en': ['e1451', 'acetyla...d oxiderad stärkelse']}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.11/v/string_type
# ❌ Invalid database entry: 2 validation errors for DatabaseEntry
# id
#   Field required [type=missing, input_value={'parents': [], 'names': ...ue, 'ecodes': ['E1452']}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.11/v/missing
# names
#   Input should be a valid string [type=string_type, input_value={'en': ['e1452', 'starch ...nium-oktenyl-succinat']}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.11/v/string_type
# ❌ Invalid database entry: 2 validation errors for DatabaseEntry
# id
#   Field required [type=missing, input_value={'parents': [], 'names': ...ue, 'ecodes': ['E1499']}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.11/v/missing
# names
#   Input should be a valid string [type=string_type, input_value={'en': ['e14xx', 'modifie... 'zh': ['化製澱粉']}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.11/v/string_type
# ❌ Invalid database entry: 2 validation errors for DatabaseEntry
# id
#   Field required [type=missing, input_value={'parents': [], 'names': ...ue, 'ecodes': ['E1503']}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.11/v/missing
# names
#   Input should be a valid string [type=string_type, input_value={'en': ['e1503', 'castor ... ['e1503', '蓖麻油']}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.11/v/string_type
# ❌ Invalid database entry: 2 validation errors for DatabaseEntry
# id
#   Field required [type=missing, input_value={'parents': [], 'names': ...ue, 'ecodes': ['E1504']}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.11/v/missing
# names
#   Input should be a valid string [type=string_type, input_value={'en': ['e1504', 'ethyl a...etyletanoat', 't-röd']}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.11/v/string_type
# ❌ Invalid database entry: 2 validation errors for DatabaseEntry
# id
#   Field required [type=missing, input_value={'parents': [], 'names': ...ue, 'ecodes': ['E1505']}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.11/v/missing
# names
#   Input should be a valid string [type=string_type, input_value={'en': ['e1505', 'triethy..., '檸檬酸三乙酯']}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.11/v/string_type
# ❌ Invalid database entry: 2 validation errors for DatabaseEntry
# id
#   Field required [type=missing, input_value={'parents': [], 'names': ...ue, 'ecodes': ['E1510']}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.11/v/missing
# names
#   Input should be a valid string [type=string_type, input_value={'en': ['e1510', 'ethanol...v': ['e1510', 'etanol']}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.11/v/string_type
# ❌ Invalid database entry: 2 validation errors for DatabaseEntry
# id
#   Field required [type=missing, input_value={'parents': [], 'names': ...ue, 'ecodes': ['E1517']}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.11/v/missing
# names
#   Input should be a valid string [type=string_type, input_value={'en': ['e1517', 'glycery...ldiacetat', 'diacetin']}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.11/v/string_type
# ❌ Invalid database entry: 2 validation errors for DatabaseEntry
# id
#   Field required [type=missing, input_value={'parents': [], 'names': ...ue, 'ecodes': ['E1518']}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.11/v/missing
# names
#   Input should be a valid string [type=string_type, input_value={'en': ['e1518', 'glycery...', 'glyceryltriacetat']}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.11/v/string_type
# ❌ Invalid database entry: 2 validation errors for DatabaseEntry
# id
#   Field required [type=missing, input_value={'parents': [], 'names': ...ue, 'ecodes': ['E1519']}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.11/v/missing
# names
#   Input should be a valid string [type=string_type, input_value={'en': ['e1519', 'benzyl ...e1519', 'benzil alkol']}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.11/v/string_type
# ❌ Invalid database entry: 2 validation errors for DatabaseEntry
# id
#   Field required [type=missing, input_value={'parents': [], 'names': ...ue, 'ecodes': ['E1520']}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.11/v/missing
# names
#   Input should be a valid string [type=string_type, input_value={'en': ['e1520', 'propyle...'propan-1\\', '2-diol']}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.11/v/string_type
# ❌ Invalid database entry: 2 validation errors for DatabaseEntry
# id
#   Field required [type=missing, input_value={'parents': [], 'names': ...ue, 'ecodes': ['E1521']}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.11/v/missing
# names
#   Input should be a valid string [type=string_type, input_value={'en': ['e1521', 'polyeth...1', 'polyetylenglykol']}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.11/v/string_type
# ❌ Invalid database entry: 2 validation errors for DatabaseEntry
# id
#   Field required [type=missing, input_value={'parents': [], 'names': ...an': None, 'ecodes': []}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.11/v/missing
# names
#   Input should be a valid string [type=string_type, input_value={'en': ['isomaltose'], 'a... 'zh': ['异麦芽糖']}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.11/v/string_type
# ❌ Invalid database entry: 2 validation errors for DatabaseEntry
# id
#   Field required [type=missing, input_value={'parents': [], 'names': ...an': None, 'ecodes': []}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.11/v/missing
# names
#   Input should be a valid string [type=string_type, input_value={'en': ['potassium iodide...'], 'zh': ['碘化钾']}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.11/v/string_type
# ❌ Invalid database entry: 2 validation errors for DatabaseEntry
# id
#   Field required [type=missing, input_value={'parents': [], 'names': ...an': None, 'ecodes': []}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.11/v/missing
# names
#   Input should be a valid string [type=string_type, input_value={'en': ['amino acids'], '...'], 'zh': ['氨基酸']}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.11/v/string_type
# ❌ Invalid database entry: 2 validation errors for DatabaseEntry
# id
#   Field required [type=missing, input_value={'parents': [], 'names': ...an': None, 'ecodes': []}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.11/v/missing
# names
#   Input should be a valid string [type=string_type, input_value={'en': ['nucleic acids'],...ici'], 'ja': ['核酸']}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.11/v/string_type
# ❌ Invalid database entry: 2 validation errors for DatabaseEntry
# id
#   Field required [type=missing, input_value={'parents': [], 'names': ...an': None, 'ecodes': []}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.11/v/missing
# names
#   Input should be a valid string [type=string_type, input_value={'en': ['organic acids'],...'], 'ja': ['有機酸']}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.11/v/string_type
# ❌ Invalid database entry: 2 validation errors for DatabaseEntry
# id
#   Field required [type=missing, input_value={'parents': [], 'names': ...an': None, 'ecodes': []}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.11/v/missing
# names
#   Input should be a valid string [type=string_type, input_value={'en': ['inorganic salts'...'], 'ja': ['無機塩']}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.11/v/string_type
# ❌ Invalid database entry: 2 validation errors for DatabaseEntry
# id
#   Field required [type=missing, input_value={'parents': ['en:e450', '...odes': ['E450', 'E500']}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.11/v/missing
# names
#   Input should be a valid string [type=string_type, input_value={'en': ['diphosphates and... en natriumcarbonaten']}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.11/v/string_type
# ❌ Invalid database entry: 2 validation errors for DatabaseEntry
# id
#   Field required [type=missing, input_value={'parents': ['en:e450(i)'...an': None, 'ecodes': []}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.11/v/missing
# names
#   Input should be a valid string [type=string_type, input_value={'ca': ['carbonat àcid d...онат натрия']}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.11/v/string_type
# ❌ Invalid database entry: 2 validation errors for DatabaseEntry
# id
#   Field required [type=missing, input_value={'parents': ['en:e450', '...an': None, 'ecodes': []}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.11/v/missing
# names
#   Input should be a valid string [type=string_type, input_value={'en': ['di- and triphosp...['di- och trifosfater']}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.11/v/string_type
# ❌ Invalid database entry: 2 validation errors for DatabaseEntry
# id
#   Field required [type=missing, input_value={'parents': ['en:e500', '...an': None, 'ecodes': []}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.11/v/missing
# names
#   Input should be a valid string [type=string_type, input_value={'en': ['ammonium and sod...carbonaten en natrium']}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.11/v/string_type
# ✅ Loaded 0 valid entries from database

# %%
def load_ingredients_from_file(file_path: str):
    """Load ingredients from uploaded JSON file"""
    print(f"Loading ingredients from {file_path}...")

    with open(file_path, 'r', encoding='utf-8') as f:
        data = json.load(f)

    ingredients = []
    skipped_count = 0

    for item in data:
        try:
            # Skip ingredients with null or empty names
            names = item.get('names')
            if not names or not isinstance(names, list) or len(names) == 0:
                skipped_count += 1
                continue

            # Keep id and all names
            ingredient = {
                'id': item['id'],
                'names': names  # Keep all names
            }
            ingredients.append(ingredient)

        except Exception as e:
            print(f"Error parsing ingredient {item.get('id', 'unknown')}: {e}")
            skipped_count += 1

    print(f"Loaded {len(ingredients)} ingredients, skipped {skipped_count} due to missing names")
    return ingredients

ingredients = load_ingredients_from_file('./exported_ingredients.json')
print(f"found ingredients {len(ingredients)}")
# Out:
# Loading ingredients from ./exported_ingredients.json...
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /tmp/ipython-input-1855612226.py in <cell line: 0>()
#      31     return ingredients
#      32
# ---> 33 ingredients = load_ingredients_from_file('./exported_ingredients.json')
#      34 print(f"found ingredients {len(ingredients)}")
#
# /tmp/ipython-input-1855612226.py in load_ingredients_from_file(file_path)
#       3     print(f"Loading ingredients from {file_path}...")
#       4
# ----> 5     with open(file_path, 'r', encoding='utf-8') as f:
#       6         data = json.load(f)
#       7
#
# FileNotFoundError: [Errno 2] No such file or directory: './exported_ingredients.json'

# %%
from pydantic import BaseModel, Field
from typing import Optional

# Pydantic model for validation
class IngredientDietaryAnalysis(BaseModel):
    """Pydantic model for ingredient dietary analysis results"""
    id: str = Field(..., description="Ingredient ID from database")
    name: str = Field(..., description="Primary ingredient name")

    # Diet compatibility
    keto: Optional[bool] = Field(None, description="Keto diet compatible")
    paleo: Optional[bool] = Field(None, description="Paleo diet compatible")
    whole30: Optional[bool] = Field(None, description="Whole30 diet compatible")
    vegan: Optional[bool] = Field(None, description="Vegan diet compatible")
    vegetarian: Optional[bool] = Field(None, description="Vegetarian diet compatible")

    # Source classification
    source: Optional[str] = Field(None, description="Primary source type of ingredient")

    # Allergen information
    contains_dairy: Optional[bool] = Field(None, description="Contains dairy products")
    contains_eggs: Optional[bool] = Field(None, description="Contains eggs")
    contains_gluten: Optional[bool] = Field(None, description="Contains gluten")
    contains_meat: Optional[bool] = Field(None, description="Contains meat")
    contains_soy: Optional[bool] = Field(None, description="Contains soy")
    contains_nuts: Optional[bool] = Field(None, description="Contains nuts")
    from_palm_oil: Optional[bool] = Field(None, description="Derived from palm oil")

    # Analysis metadata
    confidence: float = Field(..., description="Confidence score (0.0-1.0)")
    reasoning: str = Field(..., description="Brief explanation of the classification")

# Prompt constants
BASE_PROMPT = """You are a food science expert specializing in ingredient dietary classification and allergen analysis.

TASK: Analyze the following batch of food ingredients/additives and provide comprehensive dietary classification for each one.

ANALYSIS REQUIREMENTS:
For each ingredient, analyze and determine:

1. **Diet Compatibility:**
   - keto: Compatible with ketogenic diet (very low carb, high fat)
   - paleo: Compatible with paleolithic diet (no processed foods, grains, legumes, dairy)
   - whole30: Compatible with Whole30 program (no grains, dairy, legumes, sugar, alcohol)
   - vegan: Contains no animal products whatsoever
   - vegetarian: Contains no meat/fish (but may contain dairy/eggs)

2. **Source Classification:**
   Classify the PRIMARY source type. Suggested values: plant, animal, meat, dairy, insect, fruit, vegetable, grain, legume, nut, seed, spice, synthetic, mineral, unknown. You may use other appropriate descriptive terms if none of these fit.

3. **Allergen Analysis:**
   - contains_dairy: Contains milk, cheese, butter, whey, casein, etc.
   - contains_eggs: Contains eggs or egg-derived ingredients
   - contains_gluten: Contains wheat, barley, rye, or gluten-containing grains
   - contains_meat: Contains meat, poultry, fish, or meat-derived ingredients
   - contains_soy: Contains soybeans or soy-derived ingredients
   - contains_nuts: Contains tree nuts or nut-derived ingredients
   - from_palm_oil: Derived from or contains palm oil

4. **Confidence & Reasoning:**
   - Provide confidence score (0.0-1.0) based on certainty of classification
   - Give brief reasoning explaining the classification

IMPORTANT GUIDELINES:
- Use ingredient names for classification
- Consider that additives like E-codes are often synthetic
- Be conservative with allergen classifications (when in doubt, mark as true)
- For diet compatibility, consider processing and source ingredients
- Provide confidence score reflecting your certainty"""

OUTPUT_FORMAT = """OUTPUT FORMAT:
Return a valid JSON array with objects, each following this exact structure:

[
  {
    "id": "ingredient_id_from_input",
    "name": "ingredient_name",
    "keto": true/false/null,
    "paleo": true/false/null,
    "whole30": true/false/null,
    "vegan": true/false/null,
    "vegetarian": true/false/null,
    "source": "descriptive_source_type_string",
    "contains_dairy": true/false/null,
    "contains_eggs": true/false/null,
    "contains_gluten": true/false/null,
    "contains_meat": true/false/null,
    "contains_soy": true/false/null,
    "contains_nuts": true/false/null,
    "from_palm_oil": true/false/null,
    "confidence": 0.95,
    "reasoning": "Brief explanation of classification"
  }
]

Analyze each ingredient thoroughly and return the complete JSON array."""

def create_dietary_batch_prompt(ingredients: List[Dict]) -> str:
    """Create a batch prompt for dietary analysis of multiple ingredients"""

    batch_count = len(ingredients)

    prompt = f"""{BASE_PROMPT}

INPUT BATCH DATA:
{json.dumps(ingredients, indent=2)}

The output array must have exactly {batch_count} objects, one for each input ingredient.

{OUTPUT_FORMAT}"""

    return prompt

# Test the prompt builder
test_ingredients = [
    {"id": "test1", "names": ["salt"]},
    {"id": "test2", "names": ["sugar", "sucrose"]}
]

test_prompt = create_dietary_batch_prompt(test_ingredients)
print(f"Prompt length: {len(test_prompt)} characters")
print("Sample prompt (first 500 chars):")
print(test_prompt[:500] + "...")
# Out:
# Prompt length: 2995 characters
# Sample prompt (first 500 chars):
# You are a food science expert specializing in ingredient dietary classification and allergen analysis.
#
# TASK: Analyze the following batch of food ingredients/additives and provide comprehensive dietary classification for each one.
#
# ANALYSIS REQUIREMENTS:
# For each ingredient, analyze and determine:
#
# 1. **Diet Compatibility:**
#    - keto: Compatible with ketogenic diet (very low carb, high fat)
#    - paleo: Compatible with paleolithic diet (no processed foods, grains, legumes, dairy)
#    - whole30: ...

# %%
import random
from typing import Tuple

def parse_llm_response(response_text: str, expected_count: int) -> Tuple[Optional[List[IngredientDietaryAnalysis]], List[str]]:
    """Parse LLM response into IngredientDietaryAnalysis objects"""
    errors = []

    try:
        # Clean and extract JSON
        response_text = response_text.strip()
        if response_text.startswith('```json'):
            response_text = response_text[7:]
        if response_text.endswith('```'):
            response_text = response_text[:-3]
        response_text = response_text.strip()

        # Parse JSON
        json_data = json.loads(response_text)

        if not isinstance(json_data, list):
            return None, ["Response is not a JSON array"]

        if len(json_data) != expected_count:
            return None, [f"Expected {expected_count} results, got {len(json_data)}"]

        # Parse each result
        results = []
        for i, item in enumerate(json_data):
            try:
                result = IngredientDietaryAnalysis(**item)
                results.append(result)
            except Exception as e:
                errors.append(f"Error parsing item {i}: {str(e)}")

        if errors:
            return None, errors

        return results, []

    except json.JSONDecodeError as e:
        return None, [f"JSON parsing error: {str(e)}"]
    except Exception as e:
        return None, [f"Unexpected error: {str(e)}"]

class BatchProcessor:
    def __init__(self, services: Dict, max_concurrent: int = 5, batch_size: int = 50):
        self.services = services
        self.semaphore = asyncio.Semaphore(max_concurrent)
        self.batch_size = batch_size
        self.retry_queue = []
        self.completed_batches = []
        self.service_names = list(services.keys())

    def get_next_service(self) -> str:
        """Round-robin service selection"""
        return random.choice(self.service_names)

    async def process_single_batch(self, batch: List[Dict], batch_num: int, retry_count: int = 0) -> Dict:
        """Process a single batch with service round-robin"""
        async with self.semaphore:
            prompt = create_dietary_batch_prompt(batch)

            # Try up to 2 different services for this batch
            for attempt in range(2):
                service_name = self.get_next_service()
                service = self.services[service_name]

                try:
                    print(f"  Batch {batch_num} (retry {retry_count}, attempt {attempt+1}): Processing with {service_name}...")

                    response = await service.invoke_async(prompt)
                    results, errors = parse_llm_response(response, len(batch))

                    if results:
                        print(f"  ✅ Batch {batch_num} {service_name}: Successfully processed {len(results)} ingredients")
                        return {
                            'batch_number': batch_num,
                            'batch_size': len(batch),
                            'ingredient_ids': [ing['id'] for ing in batch],
                            'service_used': service_name,
                            'retry_count': retry_count,
                            'attempt': attempt + 1,
                            'success': True,
                            'results': [result.model_dump() for result in results],
                            'timestamp': datetime.now().isoformat()
                        }
                    else:
                        print(f"  ❌ Batch {batch_num} {service_name}: Parsing failed - {errors}")

                except Exception as e:
                    print(f"  ❌ Batch {batch_num} {service_name}: API failed - {str(e)}")

            # All attempts failed
            print(f"  💀 Batch {batch_num}: All attempts failed, adding to retry queue")
            return {
                'batch_number': batch_num,
                'batch_size': len(batch),
                'ingredient_ids': [ing['id'] for ing in batch],
                'service_used': None,
                'retry_count': retry_count,
                'success': False,
                'timestamp': datetime.now().isoformat()
            }

print("✅ Batch processor setup complete")
# Out:
# ✅ Batch processor setup complete

# %%
async def process_all_ingredients(ingredients: List[Dict], batch_size: int = 50, max_concurrent: int = 5, max_retries: int = 2):
    """Process all ingredients in batches with retry logic"""

    processor = BatchProcessor(services, max_concurrent, batch_size)

    # Create initial batches
    total_batches = (len(ingredients) + batch_size - 1) // batch_size
    initial_batches = []

    for i in range(0, len(ingredients), batch_size):
        batch = ingredients[i:i + batch_size]
        batch_num = i // batch_size + 1
        initial_batches.append((batch, batch_num))
        print(f"Created batch {batch_num}/{total_batches} ({len(batch)} ingredients)")

    print(f"\nProcessing {total_batches} batches with max {max_concurrent} concurrent requests...")

    # Process initial batches
    tasks = []
    for batch, batch_num in initial_batches:
        task = processor.process_single_batch(batch, batch_num, 0)
        tasks.append(task)

    # Execute all batches concurrently
    batch_results = await asyncio.gather(*tasks, return_exceptions=True)

    # Collect results and failed batches
    successful_batches = []
    failed_batches = []

    for i, result in enumerate(batch_results):
        if isinstance(result, Exception):
            print(f"❌ Batch {i+1} crashed: {result}")
            batch, batch_num = initial_batches[i]
            failed_batches.append((batch, batch_num))
        elif result['success']:
            successful_batches.append(result)
            print(f"✅ Batch {result['batch_number']} completed successfully")
        else:
            batch, batch_num = initial_batches[i]
            failed_batches.append((batch, batch_num))

    # Retry failed batches
    retry_round = 1
    while failed_batches and retry_round <= max_retries:
        print(f"\n🔄 Retry round {retry_round}: {len(failed_batches)} failed batches")

        retry_tasks = []
        current_failed = failed_batches[:]
        failed_batches = []

        for batch, batch_num in current_failed:
            task = processor.process_single_batch(batch, batch_num, retry_round)
            retry_tasks.append(task)

        retry_results = await asyncio.gather(*retry_tasks, return_exceptions=True)

        for i, result in enumerate(retry_results):
            if isinstance(result, Exception):
                print(f"❌ Retry batch {current_failed[i][1]} crashed: {result}")
                failed_batches.append(current_failed[i])
            elif result['success']:
                successful_batches.append(result)
                print(f"✅ Retry batch {result['batch_number']} completed successfully")
            else:
                failed_batches.append(current_failed[i])

        retry_round += 1

    # Final summary
    print(f"\n📊 PROCESSING SUMMARY:")
    print(f"Total ingredients: {len(ingredients)}")
    print(f"Total batches: {total_batches}")
    print(f"Successful batches: {len(successful_batches)}")
    print(f"Failed batches: {len(failed_batches)}")

    if failed_batches:
        print(f"⚠️  {len(failed_batches)} batches failed after {max_retries} retries")

    return {
        'total_ingredients': len(ingredients),
        'total_batches': total_batches,
        'successful_batches': successful_batches,
        'failed_batches': [{'batch_number': batch_num, 'ingredient_count': len(batch)} for batch, batch_num in failed_batches],
        'processing_timestamp': datetime.now().isoformat()
    }

print("✅ Main execution function ready")
# Out:
# ✅ Main execution function ready

# %%
# Process all ingredients
results = await process_all_ingredients(ingredients, batch_size=20, max_concurrent=5)

# Extract analyses from successful batches
all_analyses = []
for batch in results['successful_batches']:
    all_analyses.extend(batch['results'])

# Save results
output_file = "dietary_analysis_results.json"
with open(output_file, 'w', encoding='utf-8') as f:
    json.dump(all_analyses, f, indent=2, ensure_ascii=False)

print(f"💾 Saved {len(all_analyses)} analyses to {output_file}")
if all_analyses:
    print(f"Sample: {all_analyses[0]['name']} - Vegan: {all_analyses[0]['vegan']}")
# Out:
# Created batch 1/283 (20 ingredients)
# Created batch 2/283 (20 ingredients)
# Created batch 3/283 (20 ingredients)
# Created batch 4/283 (20 ingredients)
# Created batch 5/283 (20 ingredients)
# Created batch 6/283 (20 ingredients)
# Created batch 7/283 (20 ingredients)
# Created batch 8/283 (20 ingredients)
# Created batch 9/283 (20 ingredients)
# Created batch 10/283 (20 ingredients)
# Created batch 11/283 (20 ingredients)
# Created batch 12/283 (20 ingredients)
# Created batch 13/283 (20 ingredients)
# Created batch 14/283 (20 ingredients)
# Created batch 15/283 (20 ingredients)
# Created batch 16/283 (20 ingredients)
# Created batch 17/283 (20 ingredients)
# Created batch 18/283 (20 ingredients)
# Created batch 19/283 (20 ingredients)
# Created batch 20/283 (20 ingredients)
# Created batch 21/283 (20 ingredients)
# Created batch 22/283 (20 ingredients)
# Created batch 23/283 (20 ingredients)
# Created batch 24/283 (20 ingredients)
# Created batch 25/283 (20 ingredients)
# Created batch 26/283 (20 ingredients)
# Created batch 27/283 (20 ingredients)
# Created batch 28/283 (20 ingredients)
# Created batch 29/283 (20 ingredients)
# Created batch 30/283 (20 ingredients)
# Created batch 31/283 (20 ingredients)
# Created batch 32/283 (20 ingredients)
# Created batch 33/283 (20 ingredients)
# Created batch 34/283 (20 ingredients)
# Created batch 35/283 (20 ingredients)
# Created batch 36/283 (20 ingredients)
# Created batch 37/283 (20 ingredients)
# Created batch 38/283 (20 ingredients)
# Created batch 39/283 (20 ingredients)
# Created batch 40/283 (20 ingredients)
# Created batch 41/283 (20 ingredients)
# Created batch 42/283 (20 ingredients)
# Created batch 43/283 (20 ingredients)
# Created batch 44/283 (20 ingredients)
# Created batch 45/283 (20 ingredients)
# Created batch 46/283 (20 ingredients)
# Created batch 47/283 (20 ingredients)
# Created batch 48/283 (20 ingredients)
# Created batch 49/283 (20 ingredients)
# Created batch 50/283 (20 ingredients)
# Created batch 51/283 (20 ingredients)
# Created batch 52/283 (20 ingredients)
# Created batch 53/283 (20 ingredients)
# Created batch 54/283 (20 ingredients)
# Created batch 55/283 (20 ingredients)
# Created batch 56/283 (20 ingredients)
# Created batch 57/283 (20 ingredients)
# Created batch 58/283 (20 ingredients)
# Created batch 59/283 (20 ingredients)
# Created batch 60/283 (20 ingredients)
# Created batch 61/283 (20 ingredients)
# Created batch 62/283 (20 ingredients)
# Created batch 63/283 (20 ingredients)
# Created batch 64/283 (20 ingredients)
# Created batch 65/283 (20 ingredients)
# Created batch 66/283 (20 ingredients)
# Created batch 67/283 (20 ingredients)
# Created batch 68/283 (20 ingredients)
# Created batch 69/283 (20 ingredients)
# Created batch 70/283 (20 ingredients)
# Created batch 71/283 (20 ingredients)
# Created batch 72/283 (20 ingredients)
# Created batch 73/283 (20 ingredients)
# Created batch 74/283 (20 ingredients)
# Created batch 75/283 (20 ingredients)
# Created batch 76/283 (20 ingredients)
# Created batch 77/283 (20 ingredients)
# Created batch 78/283 (20 ingredients)
# Created batch 79/283 (20 ingredients)
# Created batch 80/283 (20 ingredients)
# Created batch 81/283 (20 ingredients)
# Created batch 82/283 (20 ingredients)
# Created batch 83/283 (20 ingredients)
# Created batch 84/283 (20 ingredients)
# Created batch 85/283 (20 ingredients)
# Created batch 86/283 (20 ingredients)
# Created batch 87/283 (20 ingredients)
# Created batch 88/283 (20 ingredients)
# Created batch 89/283 (20 ingredients)
# Created batch 90/283 (20 ingredients)
# Created batch 91/283 (20 ingredients)
# Created batch 92/283 (20 ingredients)
# Created batch 93/283 (20 ingredients)
# Created batch 94/283 (20 ingredients)
# Created batch 95/283 (20 ingredients)
# Created batch 96/283 (20 ingredients)
# Created batch 97/283 (20 ingredients)
# Created batch 98/283 (20 ingredients)
# Created batch 99/283 (20 ingredients)
# Created batch 100/283 (20 ingredients)
# Created batch 101/283 (20 ingredients)
# Created batch 102/283 (20 ingredients)
# Created batch 103/283 (20 ingredients)
# Created batch 104/283 (20 ingredients)
# Created batch 105/283 (20 ingredients)
# Created batch 106/283 (20 ingredients)
# Created batch 107/283 (20 ingredients)
# Created batch 108/283 (20 ingredients)
# Created batch 109/283 (20 ingredients)
# Created batch 110/283 (20 ingredients)
# Created batch 111/283 (20 ingredients)
# Created batch 112/283 (20 ingredients)
# Created batch 113/283 (20 ingredients)
# Created batch 114/283 (20 ingredients)
# Created batch 115/283 (20 ingredients)
# Created batch 116/283 (20 ingredients)
# Created batch 117/283 (20 ingredients)
# Created batch 118/283 (20 ingredients)
# Created batch 119/283 (20 ingredients)
# Created batch 120/283 (20 ingredients)
# Created batch 121/283 (20 ingredients)
# Created batch 122/283 (20 ingredients)
# Created batch 123/283 (20 ingredients)
# Created batch 124/283 (20 ingredients)
# Created batch 125/283 (20 ingredients)
# Created batch 126/283 (20 ingredients)
# Created batch 127/283 (20 ingredients)
# Created batch 128/283 (20 ingredients)
# Created batch 129/283 (20 ingredients)
# Created batch 130/283 (20 ingredients)
# Created batch 131/283 (20 ingredients)
# Created batch 132/283 (20 ingredients)
# Created batch 133/283 (20 ingredients)
# Created batch 134/283 (20 ingredients)
# Created batch 135/283 (20 ingredients)
# Created batch 136/283 (20 ingredients)
# Created batch 137/283 (20 ingredients)
# Created batch 138/283 (20 ingredients)
# Created batch 139/283 (20 ingredients)
# Created batch 140/283 (20 ingredients)
# Created batch 141/283 (20 ingredients)
# Created batch 142/283 (20 ingredients)
# Created batch 143/283 (20 ingredients)
# Created batch 144/283 (20 ingredients)
# Created batch 145/283 (20 ingredients)
# Created batch 146/283 (20 ingredients)
# Created batch 147/283 (20 ingredients)
# Created batch 148/283 (20 ingredients)
# Created batch 149/283 (20 ingredients)
# Created batch 150/283 (20 ingredients)
# Created batch 151/283 (20 ingredients)
# Created batch 152/283 (20 ingredients)
# Created batch 153/283 (20 ingredients)
# Created batch 154/283 (20 ingredients)
# Created batch 155/283 (20 ingredients)
# Created batch 156/283 (20 ingredients)
# Created batch 157/283 (20 ingredients)
# Created batch 158/283 (20 ingredients)
# Created batch 159/283 (20 ingredients)
# Created batch 160/283 (20 ingredients)
# Created batch 161/283 (20 ingredients)
# Created batch 162/283 (20 ingredients)
# Created batch 163/283 (20 ingredients)
# Created batch 164/283 (20 ingredients)
# Created batch 165/283 (20 ingredients)
# Created batch 166/283 (20 ingredients)
# Created batch 167/283 (20 ingredients)
# Created batch 168/283 (20 ingredients)
# Created batch 169/283 (20 ingredients)
# Created batch 170/283 (20 ingredients)
# Created batch 171/283 (20 ingredients)
# Created batch 172/283 (20 ingredients)
# Created batch 173/283 (20 ingredients)
# Created batch 174/283 (20 ingredients)
# Created batch 175/283 (20 ingredients)
# Created batch 176/283 (20 ingredients)
# Created batch 177/283 (20 ingredients)
# Created batch 178/283 (20 ingredients)
# Created batch 179/283 (20 ingredients)
# Created batch 180/283 (20 ingredients)
# Created batch 181/283 (20 ingredients)
# Created batch 182/283 (20 ingredients)
# Created batch 183/283 (20 ingredients)
# Created batch 184/283 (20 ingredients)
# Created batch 185/283 (20 ingredients)
# Created batch 186/283 (20 ingredients)
# Created batch 187/283 (20 ingredients)
# Created batch 188/283 (20 ingredients)
# Created batch 189/283 (20 ingredients)
# Created batch 190/283 (20 ingredients)
# Created batch 191/283 (20 ingredients)
# Created batch 192/283 (20 ingredients)
# Created batch 193/283 (20 ingredients)
# Created batch 194/283 (20 ingredients)
# Created batch 195/283 (20 ingredients)
# Created batch 196/283 (20 ingredients)
# Created batch 197/283 (20 ingredients)
# Created batch 198/283 (20 ingredients)
# Created batch 199/283 (20 ingredients)
# Created batch 200/283 (20 ingredients)
# Created batch 201/283 (20 ingredients)
# Created batch 202/283 (20 ingredients)
# Created batch 203/283 (20 ingredients)
# Created batch 204/283 (20 ingredients)
# Created batch 205/283 (20 ingredients)
# Created batch 206/283 (20 ingredients)
# Created batch 207/283 (20 ingredients)
# Created batch 208/283 (20 ingredients)
# Created batch 209/283 (20 ingredients)
# Created batch 210/283 (20 ingredients)
# Created batch 211/283 (20 ingredients)
# Created batch 212/283 (20 ingredients)
# Created batch 213/283 (20 ingredients)
# Created batch 214/283 (20 ingredients)
# Created batch 215/283 (20 ingredients)
# Created batch 216/283 (20 ingredients)
# Created batch 217/283 (20 ingredients)
# Created batch 218/283 (20 ingredients)
# Created batch 219/283 (20 ingredients)
# Created batch 220/283 (20 ingredients)
# Created batch 221/283 (20 ingredients)
# Created batch 222/283 (20 ingredients)
# Created batch 223/283 (20 ingredients)
# Created batch 224/283 (20 ingredients)
# Created batch 225/283 (20 ingredients)
# Created batch 226/283 (20 ingredients)
# Created batch 227/283 (20 ingredients)
# Created batch 228/283 (20 ingredients)
# Created batch 229/283 (20 ingredients)
# Created batch 230/283 (20 ingredients)
# Created batch 231/283 (20 ingredients)
# Created batch 232/283 (20 ingredients)
# Created batch 233/283 (20 ingredients)
# Created batch 234/283 (20 ingredients)
# Created batch 235/283 (20 ingredients)
# Created batch 236/283 (20 ingredients)
# Created batch 237/283 (20 ingredients)
# Created batch 238/283 (20 ingredients)
# Created batch 239/283 (20 ingredients)
# Created batch 240/283 (20 ingredients)
# Created batch 241/283 (20 ingredients)
# Created batch 242/283 (20 ingredients)
# Created batch 243/283 (20 ingredients)
# Created batch 244/283 (20 ingredients)
# Created batch 245/283 (20 ingredients)
# Created batch 246/283 (20 ingredients)
# Created batch 247/283 (20 ingredients)
# Created batch 248/283 (20 ingredients)
# Created batch 249/283 (20 ingredients)
# Created batch 250/283 (20 ingredients)
# Created batch 251/283 (20 ingredients)
# Created batch 252/283 (20 ingredients)
# Created batch 253/283 (20 ingredients)
# Created batch 254/283 (20 ingredients)
# Created batch 255/283 (20 ingredients)
# Created batch 256/283 (20 ingredients)
# Created batch 257/283 (20 ingredients)
# Created batch 258/283 (20 ingredients)
# Created batch 259/283 (20 ingredients)
# Created batch 260/283 (20 ingredients)
# Created batch 261/283 (20 ingredients)
# Created batch 262/283 (20 ingredients)
# Created batch 263/283 (20 ingredients)
# Created batch 264/283 (20 ingredients)
# Created batch 265/283 (20 ingredients)
# Created batch 266/283 (20 ingredients)
# Created batch 267/283 (20 ingredients)
# Created batch 268/283 (20 ingredients)
# Created batch 269/283 (20 ingredients)
# Created batch 270/283 (20 ingredients)
# Created batch 271/283 (20 ingredients)
# Created batch 272/283 (20 ingredients)
# Created batch 273/283 (20 ingredients)
# Created batch 274/283 (20 ingredients)
# Created batch 275/283 (20 ingredients)
# Created batch 276/283 (20 ingredients)
# Created batch 277/283 (20 ingredients)
# Created batch 278/283 (20 ingredients)
# Created batch 279/283 (20 ingredients)
# Created batch 280/283 (20 ingredients)
# Created batch 281/283 (20 ingredients)
# Created batch 282/283 (20 ingredients)
# Created batch 283/283 (1 ingredients)
#
# Processing 283 batches with max 5 concurrent requests...
#   Batch 1 (retry 0, attempt 1): Processing with deepseek...
#   Batch 2 (retry 0, attempt 1): Processing with openai...
#   Batch 3 (retry 0, attempt 1): Processing with gemini...
#   Batch 4 (retry 0, attempt 1): Processing with openai...
#   Batch 5 (retry 0, attempt 1): Processing with gemini...
#   ✅ Batch 5 gemini: Successfully processed 20 ingredients
#   Batch 6 (retry 0, attempt 1): Processing with deepseek...
#   ✅ Batch 3 gemini: Successfully processed 20 ingredients
#   Batch 7 (retry 0, attempt 1): Processing with openai...
#   ✅ Batch 4 openai: Successfully processed 20 ingredients
#   Batch 8 (retry 0, attempt 1): Processing with gemini...
#   ✅ Batch 2 openai: Successfully processed 20 ingredients
#   Batch 9 (retry 0, attempt 1): Processing with deepseek...
#   ✅ Batch 8 gemini: Successfully processed 20 ingredients
#   Batch 10 (retry 0, attempt 1): Processing with gemini...
#   ✅ Batch 7 openai: Successfully processed 20 ingredients
#   Batch 11 (retry 0, attempt 1): Processing with deepseek...
#   ✅ Batch 10 gemini: Successfully processed 20 ingredients
#   Batch 12 (retry 0, attempt 1): Processing with deepseek...
#   ✅ Batch 1 deepseek: Successfully processed 20 ingredients
#   Batch 13 (retry 0, attempt 1): Processing with gemini...
#   ✅ Batch 13 gemini: Successfully processed 20 ingredients
#   Batch 14 (retry 0, attempt 1): Processing with openai...
#   ✅ Batch 6 deepseek: Successfully processed 20 ingredients
#   Batch 15 (retry 0, attempt 1): Processing with deepseek...
#   ✅ Batch 9 deepseek: Successfully processed 20 ingredients
#   Batch 16 (retry 0, attempt 1): Processing with deepseek...
#   ✅ Batch 11 deepseek: Successfully processed 20 ingredients
#   Batch 17 (retry 0, attempt 1): Processing with deepseek...
#   ✅ Batch 14 openai: Successfully processed 20 ingredients
#   Batch 18 (retry 0, attempt 1): Processing with openai...
#   ✅ Batch 18 openai: Successfully processed 20 ingredients
#   Batch 19 (retry 0, attempt 1): Processing with gemini...
#   ✅ Batch 12 deepseek: Successfully processed 20 ingredients
#   Batch 20 (retry 0, attempt 1): Processing with gemini...
#   ✅ Batch 19 gemini: Successfully processed 20 ingredients
#   Batch 21 (retry 0, attempt 1): Processing with gemini...
#   ✅ Batch 20 gemini: Successfully processed 20 ingredients
#   Batch 22 (retry 0, attempt 1): Processing with deepseek...
#   ✅ Batch 21 gemini: Successfully processed 20 ingredients
#   Batch 23 (retry 0, attempt 1): Processing with openai...
#   ✅ Batch 16 deepseek: Successfully processed 20 ingredients
#   Batch 24 (retry 0, attempt 1): Processing with openai...
#   ✅ Batch 15 deepseek: Successfully processed 20 ingredients
#   Batch 25 (retry 0, attempt 1): Processing with gemini...
#   ✅ Batch 23 openai: Successfully processed 20 ingredients
#   Batch 26 (retry 0, attempt 1): Processing with openai...
#   ✅ Batch 17 deepseek: Successfully processed 20 ingredients
#   Batch 27 (retry 0, attempt 1): Processing with gemini...
#   ✅ Batch 25 gemini: Successfully processed 20 ingredients
#   Batch 28 (retry 0, attempt 1): Processing with gemini...
#   ✅ Batch 24 openai: Successfully processed 20 ingredients
#   Batch 29 (retry 0, attempt 1): Processing with deepseek...
#   ✅ Batch 26 openai: Successfully processed 20 ingredients
#   Batch 30 (retry 0, attempt 1): Processing with gemini...
#   ✅ Batch 27 gemini: Successfully processed 20 ingredients
#   Batch 31 (retry 0, attempt 1): Processing with gemini...
#   ✅ Batch 28 gemini: Successfully processed 20 ingredients
#   Batch 32 (retry 0, attempt 1): Processing with deepseek...
#   ✅ Batch 30 gemini: Successfully processed 20 ingredients
#   Batch 33 (retry 0, attempt 1): Processing with gemini...
#   ✅ Batch 31 gemini: Successfully processed 20 ingredients
#   Batch 34 (retry 0, attempt 1): Processing with deepseek...
#   ✅ Batch 22 deepseek: Successfully processed 20 ingredients
#   Batch 35 (retry 0, attempt 1): Processing with openai...
#   ✅ Batch 33 gemini: Successfully processed 20 ingredients
#   Batch 36 (retry 0, attempt 1): Processing with gemini...
#   ✅ Batch 35 openai: Successfully processed 20 ingredients
#   Batch 37 (retry 0, attempt 1): Processing with openai...
#   ✅ Batch 36 gemini: Successfully processed 20 ingredients
#   Batch 38 (retry 0, attempt 1): Processing with gemini...
#   ✅ Batch 38 gemini: Successfully processed 20 ingredients
#   Batch 39 (retry 0, attempt 1): Processing with deepseek...
#   ✅ Batch 37 openai: Successfully processed 20 ingredients
#   Batch 40 (retry 0, attempt 1): Processing with openai...
#   ✅ Batch 29 deepseek: Successfully processed 20 ingredients
#   Batch 41 (retry 0, attempt 1): Processing with gemini...
#   ✅ Batch 40 openai: Successfully processed 20 ingredients
#   Batch 42 (retry 0, attempt 1): Processing with deepseek...
#   ✅ Batch 41 gemini: Successfully processed 20 ingredients
#   Batch 43 (retry 0, attempt 1): Processing with deepseek...
#   ✅ Batch 34 deepseek: Successfully processed 20 ingredients
#   Batch 44 (retry 0, attempt 1): Processing with deepseek...
#   ✅ Batch 32 deepseek: Successfully processed 20 ingredients
#   Batch 45 (retry 0, attempt 1): Processing with openai...
#   ✅ Batch 45 openai: Successfully processed 20 ingredients
#   Batch 46 (retry 0, attempt 1): Processing with gemini...
#   ✅ Batch 39 deepseek: Successfully processed 20 ingredients
#   Batch 47 (retry 0, attempt 1): Processing with deepseek...
#   ✅ Batch 46 gemini: Successfully processed 20 ingredients
#   Batch 48 (retry 0, attempt 1): Processing with openai...
#   ✅ Batch 48 openai: Successfully processed 20 ingredients
#   Batch 49 (retry 0, attempt 1): Processing with deepseek...
#   ✅ Batch 42 deepseek: Successfully processed 20 ingredients
#   Batch 50 (retry 0, attempt 1): Processing with gemini...
#   ✅ Batch 43 deepseek: Successfully processed 20 ingredients
#   Batch 51 (retry 0, attempt 1): Processing with gemini...
#   ✅ Batch 50 gemini: Successfully processed 20 ingredients
#   Batch 52 (retry 0, attempt 1): Processing with gemini...
#   ✅ Batch 51 gemini: Successfully processed 20 ingredients
#   Batch 53 (retry 0, attempt 1): Processing with deepseek...
#   ✅ Batch 44 deepseek: Successfully processed 20 ingredients
#   Batch 54 (retry 0, attempt 1): Processing with openai...
#   ✅ Batch 52 gemini: Successfully processed 20 ingredients
#   Batch 55 (retry 0, attempt 1): Processing with deepseek...
#   ✅ Batch 54 openai: Successfully processed 20 ingredients
#   Batch 56 (retry 0, attempt 1): Processing with openai...
#   ✅ Batch 47 deepseek: Successfully processed 20 ingredients
#   Batch 57 (retry 0, attempt 1): Processing with deepseek...
#   ✅ Batch 56 openai: Successfully processed 20 ingredients
#   Batch 58 (retry 0, attempt 1): Processing with gemini...
#   ✅ Batch 58 gemini: Successfully processed 20 ingredients
#   Batch 59 (retry 0, attempt 1): Processing with openai...
#   ✅ Batch 49 deepseek: Successfully processed 20 ingredients
#   Batch 60 (retry 0, attempt 1): Processing with gemini...
#   ✅ Batch 60 gemini: Successfully processed 20 ingredients
#   Batch 61 (retry 0, attempt 1): Processing with openai...
#   ✅ Batch 59 openai: Successfully processed 20 ingredients
#   Batch 62 (retry 0, attempt 1): Processing with gemini...
#   ✅ Batch 53 deepseek: Successfully processed 20 ingredients
#   Batch 63 (retry 0, attempt 1): Processing with gemini...
#   ✅ Batch 61 openai: Successfully processed 20 ingredients
#   Batch 64 (retry 0, attempt 1): Processing with openai...
#   ✅ Batch 62 gemini: Successfully processed 20 ingredients
#   Batch 65 (retry 0, attempt 1): Processing with deepseek...
#   ✅ Batch 55 deepseek: Successfully processed 20 ingredients
#   Batch 66 (retry 0, attempt 1): Processing with deepseek...
#   ✅ Batch 63 gemini: Successfully processed 20 ingredients
#   Batch 67 (retry 0, attempt 1): Processing with gemini...
#   ✅ Batch 64 openai: Successfully processed 20 ingredients
#   Batch 68 (retry 0, attempt 1): Processing with gemini...
#   ✅ Batch 67 gemini: Successfully processed 20 ingredients
#   Batch 69 (retry 0, attempt 1): Processing with openai...
#   ✅ Batch 57 deepseek: Successfully processed 20 ingredients
#   Batch 70 (retry 0, attempt 1): Processing with openai...
#   ✅ Batch 68 gemini: Successfully processed 20 ingredients
#   Batch 71 (retry 0, attempt 1): Processing with openai...
#   ✅ Batch 69 openai: Successfully processed 20 ingredients
#   Batch 72 (retry 0, attempt 1): Processing with openai...
#   ✅ Batch 71 openai: Successfully processed 20 ingredients
#   Batch 73 (retry 0, attempt 1): Processing with openai...
#   ✅ Batch 70 openai: Successfully processed 20 ingredients
#   Batch 74 (retry 0, attempt 1): Processing with gemini...
#   ✅ Batch 72 openai: Successfully processed 20 ingredients
#   Batch 75 (retry 0, attempt 1): Processing with gemini...
#   ✅ Batch 74 gemini: Successfully processed 20 ingredients
#   Batch 76 (retry 0, attempt 1): Processing with gemini...
#   ✅ Batch 73 openai: Successfully processed 20 ingredients
#   Batch 77 (retry 0, attempt 1): Processing with openai...
#   ✅ Batch 75 gemini: Successfully processed 20 ingredients
#   Batch 78 (retry 0, attempt 1): Processing with gemini...
#   ✅ Batch 66 deepseek: Successfully processed 20 ingredients
#   Batch 79 (retry 0, attempt 1): Processing with gemini...
#   ✅ Batch 76 gemini: Successfully processed 20 ingredients
#   Batch 80 (retry 0, attempt 1): Processing with openai...
#   ✅ Batch 65 deepseek: Successfully processed 20 ingredients
#   Batch 81 (retry 0, attempt 1): Processing with deepseek...
#   ✅ Batch 77 openai: Successfully processed 20 ingredients
#   Batch 82 (retry 0, attempt 1): Processing with openai...
#   ✅ Batch 78 gemini: Successfully processed 20 ingredients
#   Batch 83 (retry 0, attempt 1): Processing with deepseek...
#   ✅ Batch 79 gemini: Successfully processed 20 ingredients
#   Batch 84 (retry 0, attempt 1): Processing with openai...
#   ✅ Batch 80 openai: Successfully processed 20 ingredients
#   Batch 85 (retry 0, attempt 1): Processing with gemini...
#   ✅ Batch 82 openai: Successfully processed 20 ingredients
#   Batch 86 (retry 0, attempt 1): Processing with gemini...
#   ✅ Batch 84 openai: Successfully processed 20 ingredients
#   Batch 87 (retry 0, attempt 1): Processing with gemini...
#   ✅ Batch 85 gemini: Successfully processed 20 ingredients
#   Batch 88 (retry 0, attempt 1): Processing with gemini...
#   ✅ Batch 86 gemini: Successfully processed 20 ingredients
#   Batch 89 (retry 0, attempt 1): Processing with deepseek...
#   ✅ Batch 87 gemini: Successfully processed 20 ingredients
#   Batch 90 (retry 0, attempt 1): Processing with openai...
#   ✅ Batch 88 gemini: Successfully processed 20 ingredients
#   Batch 91 (retry 0, attempt 1): Processing with openai...
#   ✅ Batch 91 openai: Successfully processed 20 ingredients
#   Batch 92 (retry 0, attempt 1): Processing with deepseek...
#   ✅ Batch 90 openai: Successfully processed 20 ingredients
#   Batch 93 (retry 0, attempt 1): Processing with openai...
#   ✅ Batch 81 deepseek: Successfully processed 20 ingredients
#   Batch 94 (retry 0, attempt 1): Processing with openai...
#   ✅ Batch 93 openai: Successfully processed 20 ingredients
#   Batch 95 (retry 0, attempt 1): Processing with deepseek...
#   ✅ Batch 83 deepseek: Successfully processed 20 ingredients
#   Batch 96 (retry 0, attempt 1): Processing with openai...
#   ✅ Batch 94 openai: Successfully processed 20 ingredients
#   Batch 97 (retry 0, attempt 1): Processing with gemini...
#   ✅ Batch 96 openai: Successfully processed 20 ingredients
#   Batch 98 (retry 0, attempt 1): Processing with gemini...
#   ✅ Batch 97 gemini: Successfully processed 20 ingredients
#   Batch 99 (retry 0, attempt 1): Processing with deepseek...
#   ✅ Batch 89 deepseek: Successfully processed 20 ingredients
#   Batch 100 (retry 0, attempt 1): Processing with deepseek...
#   ✅ Batch 98 gemini: Successfully processed 20 ingredients
#   Batch 101 (retry 0, attempt 1): Processing with deepseek...
#   ✅ Batch 92 deepseek: Successfully processed 20 ingredients
#   Batch 102 (retry 0, attempt 1): Processing with gemini...
#   ✅ Batch 102 gemini: Successfully processed 20 ingredients
#   Batch 103 (retry 0, attempt 1): Processing with openai...
#   ✅ Batch 95 deepseek: Successfully processed 20 ingredients
#   Batch 104 (retry 0, attempt 1): Processing with deepseek...
#   ✅ Batch 103 openai: Successfully processed 20 ingredients
#   Batch 105 (retry 0, attempt 1): Processing with openai...
#   ✅ Batch 99 deepseek: Successfully processed 20 ingredients
#   Batch 106 (retry 0, attempt 1): Processing with gemini...
#   ✅ Batch 100 deepseek: Successfully processed 20 ingredients
#   Batch 107 (retry 0, attempt 1): Processing with deepseek...
#   ✅ Batch 105 openai: Successfully processed 20 ingredients
#   Batch 108 (retry 0, attempt 1): Processing with openai...
#   ✅ Batch 101 deepseek: Successfully processed 20 ingredients
#   Batch 109 (retry 0, attempt 1): Processing with deepseek...
#   ✅ Batch 106 gemini: Successfully processed 20 ingredients
#   Batch 110 (retry 0, attempt 1): Processing with openai...
#   ✅ Batch 110 openai: Successfully processed 20 ingredients
#   Batch 111 (retry 0, attempt 1): Processing with deepseek...
#   ✅ Batch 108 openai: Successfully processed 20 ingredients
#   Batch 112 (retry 0, attempt 1): Processing with openai...
#   ✅ Batch 104 deepseek: Successfully processed 20 ingredients
#   Batch 113 (retry 0, attempt 1): Processing with deepseek...
#   ✅ Batch 112 openai: Successfully processed 20 ingredients
#   Batch 114 (retry 0, attempt 1): Processing with gemini...
#   ✅ Batch 114 gemini: Successfully processed 20 ingredients
#   Batch 115 (retry 0, attempt 1): Processing with deepseek...
#   ✅ Batch 107 deepseek: Successfully processed 20 ingredients
#   Batch 116 (retry 0, attempt 1): Processing with deepseek...
#   ✅ Batch 109 deepseek: Successfully processed 20 ingredients
#   Batch 117 (retry 0, attempt 1): Processing with deepseek...
#   ✅ Batch 113 deepseek: Successfully processed 20 ingredients
#   Batch 118 (retry 0, attempt 1): Processing with openai...
#   ✅ Batch 115 deepseek: Successfully processed 20 ingredients
#   Batch 119 (retry 0, attempt 1): Processing with deepseek...
#   ✅ Batch 118 openai: Successfully processed 20 ingredients
#   Batch 120 (retry 0, attempt 1): Processing with openai...
#   ✅ Batch 116 deepseek: Successfully processed 20 ingredients
#   Batch 121 (retry 0, attempt 1): Processing with gemini...
#   ✅ Batch 117 deepseek: Successfully processed 20 ingredients
#   Batch 122 (retry 0, attempt 1): Processing with deepseek...
#   ✅ Batch 121 gemini: Successfully processed 20 ingredients
#   Batch 123 (retry 0, attempt 1): Processing with deepseek...
#   ✅ Batch 120 openai: Successfully processed 20 ingredients
#   Batch 124 (retry 0, attempt 1): Processing with deepseek...
#   ✅ Batch 119 deepseek: Successfully processed 20 ingredients
#   Batch 125 (retry 0, attempt 1): Processing with deepseek...
#   ✅ Batch 124 deepseek: Successfully processed 20 ingredients
#   Batch 126 (retry 0, attempt 1): Processing with deepseek...
#   ✅ Batch 122 deepseek: Successfully processed 20 ingredients
#   Batch 127 (retry 0, attempt 1): Processing with gemini...
#   ✅ Batch 111 deepseek: Successfully processed 20 ingredients
#   Batch 128 (retry 0, attempt 1): Processing with gemini...
#   ✅ Batch 123 deepseek: Successfully processed 20 ingredients
#   Batch 129 (retry 0, attempt 1): Processing with openai...
#   ✅ Batch 127 gemini: Successfully processed 20 ingredients
#   Batch 130 (retry 0, attempt 1): Processing with deepseek...
#   ✅ Batch 128 gemini: Successfully processed 20 ingredients
#   Batch 131 (retry 0, attempt 1): Processing with deepseek...
#   ✅ Batch 129 openai: Successfully processed 20 ingredients
#   Batch 132 (retry 0, attempt 1): Processing with openai...
#   ✅ Batch 132 openai: Successfully processed 20 ingredients
#   Batch 133 (retry 0, attempt 1): Processing with gemini...
#   ✅ Batch 133 gemini: Successfully processed 20 ingredients
#   Batch 134 (retry 0, attempt 1): Processing with gemini...
#   ✅ Batch 125 deepseek: Successfully processed 20 ingredients
#   Batch 135 (retry 0, attempt 1): Processing with deepseek...
#   ✅ Batch 134 gemini: Successfully processed 20 ingredients
#   Batch 136 (retry 0, attempt 1): Processing with openai...
#   ✅ Batch 126 deepseek: Successfully processed 20 ingredients
#   Batch 137 (retry 0, attempt 1): Processing with openai...
#   ✅ Batch 136 openai: Successfully processed 20 ingredients
#   Batch 138 (retry 0, attempt 1): Processing with openai...
#   ✅ Batch 131 deepseek: Successfully processed 20 ingredients
#   Batch 139 (retry 0, attempt 1): Processing with deepseek...
#   ✅ Batch 130 deepseek: Successfully processed 20 ingredients
#   Batch 140 (retry 0, attempt 1): Processing with openai...
#   ✅ Batch 137 openai: Successfully processed 20 ingredients
#   Batch 141 (retry 0, attempt 1): Processing with openai...
#   ✅ Batch 140 openai: Successfully processed 20 ingredients
#   Batch 142 (retry 0, attempt 1): Processing with openai...
#   ✅ Batch 141 openai: Successfully processed 20 ingredients
#   Batch 143 (retry 0, attempt 1): Processing with deepseek...
#   ✅ Batch 138 openai: Successfully processed 20 ingredients
#   Batch 144 (retry 0, attempt 1): Processing with openai...
#   ✅ Batch 142 openai: Successfully processed 20 ingredients
#   Batch 145 (retry 0, attempt 1): Processing with gemini...
#   ✅ Batch 144 openai: Successfully processed 20 ingredients
#   Batch 146 (retry 0, attempt 1): Processing with gemini...
#   ✅ Batch 135 deepseek: Successfully processed 20 ingredients
#   Batch 147 (retry 0, attempt 1): Processing with deepseek...
#   ✅ Batch 145 gemini: Successfully processed 20 ingredients
#   Batch 148 (retry 0, attempt 1): Processing with deepseek...
#   ✅ Batch 146 gemini: Successfully processed 20 ingredients
#   Batch 149 (retry 0, attempt 1): Processing with deepseek...
#   ✅ Batch 139 deepseek: Successfully processed 20 ingredients
#   Batch 150 (retry 0, attempt 1): Processing with openai...
#   ✅ Batch 150 openai: Successfully processed 20 ingredients
#   Batch 151 (retry 0, attempt 1): Processing with gemini...
#   ✅ Batch 151 gemini: Successfully processed 20 ingredients
#   Batch 152 (retry 0, attempt 1): Processing with openai...
#   ✅ Batch 147 deepseek: Successfully processed 20 ingredients
#   Batch 153 (retry 0, attempt 1): Processing with deepseek...
#   ✅ Batch 148 deepseek: Successfully processed 20 ingredients
#   Batch 154 (retry 0, attempt 1): Processing with deepseek...
#   ✅ Batch 152 openai: Successfully processed 20 ingredients
#   Batch 155 (retry 0, attempt 1): Processing with openai...
#   ✅ Batch 149 deepseek: Successfully processed 20 ingredients
#   Batch 156 (retry 0, attempt 1): Processing with openai...
#   ✅ Batch 143 deepseek: Successfully processed 20 ingredients
#   Batch 157 (retry 0, attempt 1): Processing with deepseek...
#   ✅ Batch 156 openai: Successfully processed 20 ingredients
#   Batch 158 (retry 0, attempt 1): Processing with gemini...
#   ✅ Batch 158 gemini: Successfully processed 20 ingredients
#   Batch 159 (retry 0, attempt 1): Processing with deepseek...
#   ✅ Batch 155 openai: Successfully processed 20 ingredients
#   Batch 160 (retry 0, attempt 1): Processing with openai...
#   ✅ Batch 160 openai: Successfully processed 20 ingredients
#   Batch 161 (retry 0, attempt 1): Processing with openai...
#   ✅ Batch 154 deepseek: Successfully processed 20 ingredients
#   Batch 162 (retry 0, attempt 1): Processing with deepseek...
#   ✅ Batch 153 deepseek: Successfully processed 20 ingredients
#   Batch 163 (retry 0, attempt 1): Processing with deepseek...
#   ✅ Batch 161 openai: Successfully processed 20 ingredients
#   Batch 164 (retry 0, attempt 1): Processing with openai...
#   ✅ Batch 157 deepseek: Successfully processed 20 ingredients
#   Batch 165 (retry 0, attempt 1): Processing with openai...
#   ✅ Batch 164 openai: Successfully processed 20 ingredients
#   Batch 166 (retry 0, attempt 1): Processing with deepseek...
#   ❌ Batch 165 openai: Parsing failed - ['Expected 20 results, got 19']
#   Batch 165 (retry 0, attempt 2): Processing with gemini...
#   ✅ Batch 165 gemini: Successfully processed 20 ingredients
#   Batch 167 (retry 0, attempt 1): Processing with deepseek...
#   ✅ Batch 159 deepseek: Successfully processed 20 ingredients
#   Batch 168 (retry 0, attempt 1): Processing with gemini...
#   ✅ Batch 168 gemini: Successfully processed 20 ingredients
#   Batch 169 (retry 0, attempt 1): Processing with openai...
#   ✅ Batch 163 deepseek: Successfully processed 20 ingredients
#   Batch 170 (retry 0, attempt 1): Processing with deepseek...
#   ✅ Batch 162 deepseek: Successfully processed 20 ingredients
#   Batch 171 (retry 0, attempt 1): Processing with gemini...
#   ✅ Batch 169 openai: Successfully processed 20 ingredients
#   Batch 172 (retry 0, attempt 1): Processing with deepseek...
#   ✅ Batch 171 gemini: Successfully processed 20 ingredients
#   Batch 173 (retry 0, attempt 1): Processing with gemini...
#   ✅ Batch 166 deepseek: Successfully processed 20 ingredients
#   Batch 174 (retry 0, attempt 1): Processing with deepseek...
#   ✅ Batch 173 gemini: Successfully processed 20 ingredients
#   Batch 175 (retry 0, attempt 1): Processing with gemini...
#   ✅ Batch 167 deepseek: Successfully processed 20 ingredients
#   Batch 176 (retry 0, attempt 1): Processing with openai...
#   ✅ Batch 175 gemini: Successfully processed 20 ingredients
#   Batch 177 (retry 0, attempt 1): Processing with deepseek...
#   ✅ Batch 176 openai: Successfully processed 20 ingredients
#   Batch 178 (retry 0, attempt 1): Processing with gemini...
#   ✅ Batch 178 gemini: Successfully processed 20 ingredients
#   Batch 179 (retry 0, attempt 1): Processing with openai...
#   ✅ Batch 170 deepseek: Successfully processed 20 ingredients
#   Batch 180 (retry 0, attempt 1): Processing with deepseek...
#   ✅ Batch 172 deepseek: Successfully processed 20 ingredients
#   Batch 181 (retry 0, attempt 1): Processing with gemini...
#   ✅ Batch 181 gemini: Successfully processed 20 ingredients
#   Batch 182 (retry 0, attempt 1): Processing with deepseek...
#   ✅ Batch 179 openai: Successfully processed 20 ingredients
#   Batch 183 (retry 0, attempt 1): Processing with openai...
#   ✅ Batch 174 deepseek: Successfully processed 20 ingredients
#   Batch 184 (retry 0, attempt 1): Processing with deepseek...
#   ✅ Batch 183 openai: Successfully processed 20 ingredients
#   Batch 185 (retry 0, attempt 1): Processing with gemini...
#   ✅ Batch 185 gemini: Successfully processed 20 ingredients
#   Batch 186 (retry 0, attempt 1): Processing with gemini...
#   ✅ Batch 186 gemini: Successfully processed 20 ingredients
#   Batch 187 (retry 0, attempt 1): Processing with openai...
#   ✅ Batch 180 deepseek: Successfully processed 20 ingredients
#   Batch 188 (retry 0, attempt 1): Processing with deepseek...
#   ✅ Batch 187 openai: Successfully processed 20 ingredients
#   Batch 189 (retry 0, attempt 1): Processing with openai...
#   ✅ Batch 189 openai: Successfully processed 20 ingredients
#   Batch 190 (retry 0, attempt 1): Processing with openai...
#   ✅ Batch 177 deepseek: Successfully processed 20 ingredients
#   Batch 191 (retry 0, attempt 1): Processing with deepseek...
#   ✅ Batch 184 deepseek: Successfully processed 20 ingredients
#   Batch 192 (retry 0, attempt 1): Processing with deepseek...
#   ✅ Batch 190 openai: Successfully processed 20 ingredients
#   Batch 193 (retry 0, attempt 1): Processing with gemini...
#   ✅ Batch 182 deepseek: Successfully processed 20 ingredients
#   Batch 194 (retry 0, attempt 1): Processing with gemini...
#   ✅ Batch 193 gemini: Successfully processed 20 ingredients
#   Batch 195 (retry 0, attempt 1): Processing with openai...
#   ✅ Batch 194 gemini: Successfully processed 20 ingredients
#   Batch 196 (retry 0, attempt 1): Processing with deepseek...
#   ✅ Batch 195 openai: Successfully processed 20 ingredients
#   Batch 197 (retry 0, attempt 1): Processing with openai...
#   ✅ Batch 188 deepseek: Successfully processed 20 ingredients
#   Batch 198 (retry 0, attempt 1): Processing with openai...
#   ✅ Batch 197 openai: Successfully processed 20 ingredients
#   Batch 199 (retry 0, attempt 1): Processing with openai...
#   ✅ Batch 198 openai: Successfully processed 20 ingredients
#   Batch 200 (retry 0, attempt 1): Processing with gemini...
#   ✅ Batch 191 deepseek: Successfully processed 20 ingredients
#   Batch 201 (retry 0, attempt 1): Processing with deepseek...
#   ✅ Batch 200 gemini: Successfully processed 20 ingredients
#   Batch 202 (retry 0, attempt 1): Processing with deepseek...
#   ✅ Batch 192 deepseek: Successfully processed 20 ingredients
#   Batch 203 (retry 0, attempt 1): Processing with openai...
#   ✅ Batch 199 openai: Successfully processed 20 ingredients
#   Batch 204 (retry 0, attempt 1): Processing with openai...
#   ✅ Batch 203 openai: Successfully processed 20 ingredients
#   Batch 205 (retry 0, attempt 1): Processing with gemini...
#   ✅ Batch 204 openai: Successfully processed 20 ingredients
#   Batch 206 (retry 0, attempt 1): Processing with openai...
#   ✅ Batch 196 deepseek: Successfully processed 20 ingredients
#   Batch 207 (retry 0, attempt 1): Processing with gemini...
#   ✅ Batch 205 gemini: Successfully processed 20 ingredients
#   Batch 208 (retry 0, attempt 1): Processing with openai...
#   ✅ Batch 207 gemini: Successfully processed 20 ingredients
#   Batch 209 (retry 0, attempt 1): Processing with deepseek...
#   ✅ Batch 206 openai: Successfully processed 20 ingredients
#   Batch 210 (retry 0, attempt 1): Processing with gemini...
#   ✅ Batch 208 openai: Successfully processed 20 ingredients
#   Batch 211 (retry 0, attempt 1): Processing with openai...
#   ✅ Batch 210 gemini: Successfully processed 20 ingredients
#   Batch 212 (retry 0, attempt 1): Processing with gemini...
#   ✅ Batch 212 gemini: Successfully processed 20 ingredients
#   Batch 213 (retry 0, attempt 1): Processing with deepseek...
#   ✅ Batch 201 deepseek: Successfully processed 20 ingredients
#   Batch 214 (retry 0, attempt 1): Processing with gemini...
#   ✅ Batch 211 openai: Successfully processed 20 ingredients
#   Batch 215 (retry 0, attempt 1): Processing with deepseek...
#   ✅ Batch 202 deepseek: Successfully processed 20 ingredients
#   Batch 216 (retry 0, attempt 1): Processing with deepseek...
#   ✅ Batch 214 gemini: Successfully processed 20 ingredients
#   Batch 217 (retry 0, attempt 1): Processing with gemini...
#   ✅ Batch 217 gemini: Successfully processed 20 ingredients
#   Batch 218 (retry 0, attempt 1): Processing with deepseek...
#   ✅ Batch 209 deepseek: Successfully processed 20 ingredients
#   Batch 219 (retry 0, attempt 1): Processing with openai...
#   ✅ Batch 219 openai: Successfully processed 20 ingredients
#   Batch 220 (retry 0, attempt 1): Processing with openai...
#   ✅ Batch 220 openai: Successfully processed 20 ingredients
#   Batch 221 (retry 0, attempt 1): Processing with gemini...
#   ✅ Batch 215 deepseek: Successfully processed 20 ingredients
#   Batch 222 (retry 0, attempt 1): Processing with deepseek...
#   ✅ Batch 216 deepseek: Successfully processed 20 ingredients
#   Batch 223 (retry 0, attempt 1): Processing with gemini...
#   ✅ Batch 221 gemini: Successfully processed 20 ingredients
#   Batch 224 (retry 0, attempt 1): Processing with gemini...
#   ✅ Batch 223 gemini: Successfully processed 20 ingredients
#   Batch 225 (retry 0, attempt 1): Processing with openai...
#   ✅ Batch 224 gemini: Successfully processed 20 ingredients
#   Batch 226 (retry 0, attempt 1): Processing with gemini...
#   ✅ Batch 225 openai: Successfully processed 20 ingredients
#   Batch 227 (retry 0, attempt 1): Processing with deepseek...
#   ✅ Batch 226 gemini: Successfully processed 20 ingredients
#   Batch 228 (retry 0, attempt 1): Processing with openai...
#   ✅ Batch 218 deepseek: Successfully processed 20 ingredients
#   Batch 229 (retry 0, attempt 1): Processing with gemini...
#   ✅ Batch 213 deepseek: Successfully processed 20 ingredients
#   Batch 230 (retry 0, attempt 1): Processing with gemini...
#   ✅ Batch 228 openai: Successfully processed 20 ingredients
#   Batch 231 (retry 0, attempt 1): Processing with gemini...
#   ✅ Batch 229 gemini: Successfully processed 20 ingredients
#   Batch 232 (retry 0, attempt 1): Processing with deepseek...
#   ✅ Batch 231 gemini: Successfully processed 20 ingredients
#   Batch 233 (retry 0, attempt 1): Processing with openai...
#   ✅ Batch 230 gemini: Successfully processed 20 ingredients
#   Batch 234 (retry 0, attempt 1): Processing with deepseek...
#   ✅ Batch 233 openai: Successfully processed 20 ingredients
#   Batch 235 (retry 0, attempt 1): Processing with deepseek...
#   ✅ Batch 227 deepseek: Successfully processed 20 ingredients
#   Batch 236 (retry 0, attempt 1): Processing with deepseek...
#   ✅ Batch 234 deepseek: Successfully processed 20 ingredients
#   Batch 237 (retry 0, attempt 1): Processing with deepseek...
#   ✅ Batch 232 deepseek: Successfully processed 20 ingredients
#   Batch 238 (retry 0, attempt 1): Processing with openai...
#   ✅ Batch 238 openai: Successfully processed 20 ingredients
#   Batch 239 (retry 0, attempt 1): Processing with openai...
#   ✅ Batch 235 deepseek: Successfully processed 20 ingredients
#   Batch 240 (retry 0, attempt 1): Processing with deepseek...
#   ✅ Batch 239 openai: Successfully processed 20 ingredients
#   Batch 241 (retry 0, attempt 1): Processing with deepseek...
#   ✅ Batch 222 deepseek: Successfully processed 20 ingredients
#   Batch 242 (retry 0, attempt 1): Processing with gemini...
#   ✅ Batch 236 deepseek: Successfully processed 20 ingredients
#   Batch 243 (retry 0, attempt 1): Processing with openai...
#   ✅ Batch 242 gemini: Successfully processed 20 ingredients
#   Batch 244 (retry 0, attempt 1): Processing with deepseek...
#   ✅ Batch 243 openai: Successfully processed 20 ingredients
#   Batch 245 (retry 0, attempt 1): Processing with deepseek...
#   ✅ Batch 237 deepseek: Successfully processed 20 ingredients
#   Batch 246 (retry 0, attempt 1): Processing with openai...
#   ✅ Batch 246 openai: Successfully processed 20 ingredients
#   Batch 247 (retry 0, attempt 1): Processing with deepseek...
#   ✅ Batch 240 deepseek: Successfully processed 20 ingredients
#   Batch 248 (retry 0, attempt 1): Processing with openai...
#   ✅ Batch 241 deepseek: Successfully processed 20 ingredients
#   Batch 249 (retry 0, attempt 1): Processing with gemini...
#   ✅ Batch 248 openai: Successfully processed 20 ingredients
#   Batch 250 (retry 0, attempt 1): Processing with deepseek...
#   ✅ Batch 249 gemini: Successfully processed 20 ingredients
#   Batch 251 (retry 0, attempt 1): Processing with openai...
#   ✅ Batch 244 deepseek: Successfully processed 20 ingredients
#   Batch 252 (retry 0, attempt 1): Processing with openai...
#   ✅ Batch 245 deepseek: Successfully processed 20 ingredients
#   Batch 253 (retry 0, attempt 1): Processing with deepseek...
#   ✅ Batch 251 openai: Successfully processed 20 ingredients
#   Batch 254 (retry 0, attempt 1): Processing with gemini...
#   ✅ Batch 252 openai: Successfully processed 20 ingredients
#   Batch 255 (retry 0, attempt 1): Processing with openai...
#   ✅ Batch 254 gemini: Successfully processed 20 ingredients
#   Batch 256 (retry 0, attempt 1): Processing with deepseek...
#   ✅ Batch 255 openai: Successfully processed 20 ingredients
#   Batch 257 (retry 0, attempt 1): Processing with deepseek...
#   ✅ Batch 247 deepseek: Successfully processed 20 ingredients
#   Batch 258 (retry 0, attempt 1): Processing with gemini...
#   ✅ Batch 258 gemini: Successfully processed 20 ingredients
#   Batch 259 (retry 0, attempt 1): Processing with openai...
#   ✅ Batch 250 deepseek: Successfully processed 20 ingredients
#   Batch 260 (retry 0, attempt 1): Processing with deepseek...
#   ✅ Batch 259 openai: Successfully processed 20 ingredients
#   Batch 261 (retry 0, attempt 1): Processing with openai...
#   ❌ Batch 253 deepseek: Parsing failed - ["Error parsing item 2: 1 validation error for IngredientDietaryAnalysis\nconfidence\n  Field required [type=missing, input_value={'id': '9e4d112a-25eb-484...due to potential carbs'}, input_type=dict]\n    For further information visit https://errors.pydantic.dev/2.11/v/missing"]
#   Batch 253 (retry 0, attempt 2): Processing with openai...
#   ✅ Batch 261 openai: Successfully processed 20 ingredients
#   Batch 262 (retry 0, attempt 1): Processing with openai...
#   ✅ Batch 253 openai: Successfully processed 20 ingredients
#   Batch 263 (retry 0, attempt 1): Processing with deepseek...
#   ✅ Batch 256 deepseek: Successfully processed 20 ingredients
#   Batch 264 (retry 0, attempt 1): Processing with openai...
#   ✅ Batch 262 openai: Successfully processed 20 ingredients
#   Batch 265 (retry 0, attempt 1): Processing with deepseek...
#   ✅ Batch 257 deepseek: Successfully processed 20 ingredients
#   Batch 266 (retry 0, attempt 1): Processing with openai...
#   ✅ Batch 264 openai: Successfully processed 20 ingredients
#   Batch 267 (retry 0, attempt 1): Processing with openai...
#   ✅ Batch 266 openai: Successfully processed 20 ingredients
#   Batch 268 (retry 0, attempt 1): Processing with gemini...
#   ✅ Batch 267 openai: Successfully processed 20 ingredients
#   Batch 269 (retry 0, attempt 1): Processing with openai...
#   ✅ Batch 268 gemini: Successfully processed 20 ingredients
#   Batch 270 (retry 0, attempt 1): Processing with deepseek...
#   ✅ Batch 269 openai: Successfully processed 20 ingredients
#   Batch 271 (retry 0, attempt 1): Processing with gemini...
#   ✅ Batch 271 gemini: Successfully processed 20 ingredients
#   Batch 272 (retry 0, attempt 1): Processing with deepseek...
#   ✅ Batch 260 deepseek: Successfully processed 20 ingredients
#   Batch 273 (retry 0, attempt 1): Processing with openai...
#   ✅ Batch 265 deepseek: Successfully processed 20 ingredients
#   Batch 274 (retry 0, attempt 1): Processing with gemini...
#   ✅ Batch 263 deepseek: Successfully processed 20 ingredients
#   Batch 275 (retry 0, attempt 1): Processing with openai...
#   ✅ Batch 274 gemini: Successfully processed 20 ingredients
#   Batch 276 (retry 0, attempt 1): Processing with gemini...
#   ✅ Batch 273 openai: Successfully processed 20 ingredients
#   Batch 277 (retry 0, attempt 1): Processing with gemini...
#   ✅ Batch 270 deepseek: Successfully processed 20 ingredients
#   Batch 278 (retry 0, attempt 1): Processing with gemini...
#   ✅ Batch 276 gemini: Successfully processed 20 ingredients
#   Batch 279 (retry 0, attempt 1): Processing with openai...
#   ✅ Batch 277 gemini: Successfully processed 20 ingredients
#   Batch 280 (retry 0, attempt 1): Processing with deepseek...
#   ✅ Batch 275 openai: Successfully processed 20 ingredients
#   Batch 281 (retry 0, attempt 1): Processing with openai...
#   ✅ Batch 278 gemini: Successfully processed 20 ingredients
#   Batch 282 (retry 0, attempt 1): Processing with gemini...
#   ✅ Batch 279 openai: Successfully processed 20 ingredients
#   Batch 283 (retry 0, attempt 1): Processing with openai...
#   ✅ Batch 283 openai: Successfully processed 1 ingredients
#   ✅ Batch 282 gemini: Successfully processed 20 ingredients
#   ✅ Batch 281 openai: Successfully processed 20 ingredients
#   ✅ Batch 272 deepseek: Successfully processed 20 ingredients
#   ✅ Batch 280 deepseek: Successfully processed 20 ingredients
# ✅ Batch 1 completed successfully
# ✅ Batch 2 completed successfully
# ✅ Batch 3 completed successfully
# ✅ Batch 4 completed successfully
# ✅ Batch 5 completed successfully
# ✅ Batch 6 completed successfully
# ✅ Batch 7 completed successfully
# ✅ Batch 8 completed successfully
# ✅ Batch 9 completed successfully
# ✅ Batch 10 completed successfully
# ✅ Batch 11 completed successfully
# ✅ Batch 12 completed successfully
# ✅ Batch 13 completed successfully
# ✅ Batch 14 completed successfully
# ✅ Batch 15 completed successfully
# ✅ Batch 16 completed successfully
# ✅ Batch 17 completed successfully
# ✅ Batch 18 completed successfully
# ✅ Batch 19 completed successfully
# ✅ Batch 20 completed successfully
# ✅ Batch 21 completed successfully
# ✅ Batch 22 completed successfully
# ✅ Batch 23 completed successfully
# ✅ Batch 24 completed successfully
# ✅ Batch 25 completed successfully
# ✅ Batch 26 completed successfully
# ✅ Batch 27 completed successfully
# ✅ Batch 28 completed successfully
# ✅ Batch 29 completed successfully
# ✅ Batch 30 completed successfully
# ✅ Batch 31 completed successfully
# ✅ Batch 32 completed successfully
# ✅ Batch 33 completed successfully
# ✅ Batch 34 completed successfully
# ✅ Batch 35 completed successfully
# ✅ Batch 36 completed successfully
# ✅ Batch 37 completed successfully
# ✅ Batch 38 completed successfully
# ✅ Batch 39 completed successfully
# ✅ Batch 40 completed successfully
# ✅ Batch 41 completed successfully
# ✅ Batch 42 completed successfully
# ✅ Batch 43 completed successfully
# ✅ Batch 44 completed successfully
# ✅ Batch 45 completed successfully
# ✅ Batch 46 completed successfully
# ✅ Batch 47 completed successfully
# ✅ Batch 48 completed successfully
# ✅ Batch 49 completed successfully
# ✅ Batch 50 completed successfully
# ✅ Batch 51 completed successfully
# ✅ Batch 52 completed successfully
# ✅ Batch 53 completed successfully
# ✅ Batch 54 completed successfully
# ✅ Batch 55 completed successfully
# ✅ Batch 56 completed successfully
# ✅ Batch 57 completed successfully
# ✅ Batch 58 completed successfully
# ✅ Batch 59 completed successfully
# ✅ Batch 60 completed successfully
# ✅ Batch 61 completed successfully
# ✅ Batch 62 completed successfully
# ✅ Batch 63 completed successfully
# ✅ Batch 64 completed successfully
# ✅ Batch 65 completed successfully
# ✅ Batch 66 completed successfully
# ✅ Batch 67 completed successfully
# ✅ Batch 68 completed successfully
# ✅ Batch 69 completed successfully
# ✅ Batch 70 completed successfully
# ✅ Batch 71 completed successfully
# ✅ Batch 72 completed successfully
# ✅ Batch 73 completed successfully
# ✅ Batch 74 completed successfully
# ✅ Batch 75 completed successfully
# ✅ Batch 76 completed successfully
# ✅ Batch 77 completed successfully
# ✅ Batch 78 completed successfully
# ✅ Batch 79 completed successfully
# ✅ Batch 80 completed successfully
# ✅ Batch 81 completed successfully
# ✅ Batch 82 completed successfully
# ✅ Batch 83 completed successfully
# ✅ Batch 84 completed successfully
# ✅ Batch 85 completed successfully
# ✅ Batch 86 completed successfully
# ✅ Batch 87 completed successfully
# ✅ Batch 88 completed successfully
# ✅ Batch 89 completed successfully
# ✅ Batch 90 completed successfully
# ✅ Batch 91 completed successfully
# ✅ Batch 92 completed successfully
# ✅ Batch 93 completed successfully
# ✅ Batch 94 completed successfully
# ✅ Batch 95 completed successfully
# ✅ Batch 96 completed successfully
# ✅ Batch 97 completed successfully
# ✅ Batch 98 completed successfully
# ✅ Batch 99 completed successfully
# ✅ Batch 100 completed successfully
# ✅ Batch 101 completed successfully
# ✅ Batch 102 completed successfully
# ✅ Batch 103 completed successfully
# ✅ Batch 104 completed successfully
# ✅ Batch 105 completed successfully
# ✅ Batch 106 completed successfully
# ✅ Batch 107 completed successfully
# ✅ Batch 108 completed successfully
# ✅ Batch 109 completed successfully
# ✅ Batch 110 completed successfully
# ✅ Batch 111 completed successfully
# ✅ Batch 112 completed successfully
# ✅ Batch 113 completed successfully
# ✅ Batch 114 completed successfully
# ✅ Batch 115 completed successfully
# ✅ Batch 116 completed successfully
# ✅ Batch 117 completed successfully
# ✅ Batch 118 completed successfully
# ✅ Batch 119 completed successfully
# ✅ Batch 120 completed successfully
# ✅ Batch 121 completed successfully
# ✅ Batch 122 completed successfully
# ✅ Batch 123 completed successfully
# ✅ Batch 124 completed successfully
# ✅ Batch 125 completed successfully
# ✅ Batch 126 completed successfully
# ✅ Batch 127 completed successfully
# ✅ Batch 128 completed successfully
# ✅ Batch 129 completed successfully
# ✅ Batch 130 completed successfully
# ✅ Batch 131 completed successfully
# ✅ Batch 132 completed successfully
# ✅ Batch 133 completed successfully
# ✅ Batch 134 completed successfully
# ✅ Batch 135 completed successfully
# ✅ Batch 136 completed successfully
# ✅ Batch 137 completed successfully
# ✅ Batch 138 completed successfully
# ✅ Batch 139 completed successfully
# ✅ Batch 140 completed successfully
# ✅ Batch 141 completed successfully
# ✅ Batch 142 completed successfully
# ✅ Batch 143 completed successfully
# ✅ Batch 144 completed successfully
# ✅ Batch 145 completed successfully
# ✅ Batch 146 completed successfully
# ✅ Batch 147 completed successfully
# ✅ Batch 148 completed successfully
# ✅ Batch 149 completed successfully
# ✅ Batch 150 completed successfully
# ✅ Batch 151 completed successfully
# ✅ Batch 152 completed successfully
# ✅ Batch 153 completed successfully
# ✅ Batch 154 completed successfully
# ✅ Batch 155 completed successfully
# ✅ Batch 156 completed successfully
# ✅ Batch 157 completed successfully
# ✅ Batch 158 completed successfully
# ✅ Batch 159 completed successfully
# ✅ Batch 160 completed successfully
# ✅ Batch 161 completed successfully
# ✅ Batch 162 completed successfully
# ✅ Batch 163 completed successfully
# ✅ Batch 164 completed successfully
# ✅ Batch 165 completed successfully
# ✅ Batch 166 completed successfully
# ✅ Batch 167 completed successfully
# ✅ Batch 168 completed successfully
# ✅ Batch 169 completed successfully
# ✅ Batch 170 completed successfully
# ✅ Batch 171 completed successfully
# ✅ Batch 172 completed successfully
# ✅ Batch 173 completed successfully
# ✅ Batch 174 completed successfully
# ✅ Batch 175 completed successfully
# ✅ Batch 176 completed successfully
# ✅ Batch 177 completed successfully
# ✅ Batch 178 completed successfully
# ✅ Batch 179 completed successfully
# ✅ Batch 180 completed successfully
# ✅ Batch 181 completed successfully
# ✅ Batch 182 completed successfully
# ✅ Batch 183 completed successfully
# ✅ Batch 184 completed successfully
# ✅ Batch 185 completed successfully
# ✅ Batch 186 completed successfully
# ✅ Batch 187 completed successfully
# ✅ Batch 188 completed successfully
# ✅ Batch 189 completed successfully
# ✅ Batch 190 completed successfully
# ✅ Batch 191 completed successfully
# ✅ Batch 192 completed successfully
# ✅ Batch 193 completed successfully
# ✅ Batch 194 completed successfully
# ✅ Batch 195 completed successfully
# ✅ Batch 196 completed successfully
# ✅ Batch 197 completed successfully
# ✅ Batch 198 completed successfully
# ✅ Batch 199 completed successfully
# ✅ Batch 200 completed successfully
# ✅ Batch 201 completed successfully
# ✅ Batch 202 completed successfully
# ✅ Batch 203 completed successfully
# ✅ Batch 204 completed successfully
# ✅ Batch 205 completed successfully
# ✅ Batch 206 completed successfully
# ✅ Batch 207 completed successfully
# ✅ Batch 208 completed successfully
# ✅ Batch 209 completed successfully
# ✅ Batch 210 completed successfully
# ✅ Batch 211 completed successfully
# ✅ Batch 212 completed successfully
# ✅ Batch 213 completed successfully
# ✅ Batch 214 completed successfully
# ✅ Batch 215 completed successfully
# ✅ Batch 216 completed successfully
# ✅ Batch 217 completed successfully
# ✅ Batch 218 completed successfully
# ✅ Batch 219 completed successfully
# ✅ Batch 220 completed successfully
# ✅ Batch 221 completed successfully
# ✅ Batch 222 completed successfully
# ✅ Batch 223 completed successfully
# ✅ Batch 224 completed successfully
# ✅ Batch 225 completed successfully
# ✅ Batch 226 completed successfully
# ✅ Batch 227 completed successfully
# ✅ Batch 228 completed successfully
# ✅ Batch 229 completed successfully
# ✅ Batch 230 completed successfully
# ✅ Batch 231 completed successfully
# ✅ Batch 232 completed successfully
# ✅ Batch 233 completed successfully
# ✅ Batch 234 completed successfully
# ✅ Batch 235 completed successfully
# ✅ Batch 236 completed successfully
# ✅ Batch 237 completed successfully
# ✅ Batch 238 completed successfully
# ✅ Batch 239 completed successfully
# ✅ Batch 240 completed successfully
# ✅ Batch 241 completed successfully
# ✅ Batch 242 completed successfully
# ✅ Batch 243 completed successfully
# ✅ Batch 244 completed successfully
# ✅ Batch 245 completed successfully
# ✅ Batch 246 completed successfully
# ✅ Batch 247 completed successfully
# ✅ Batch 248 completed successfully
# ✅ Batch 249 completed successfully
# ✅ Batch 250 completed successfully
# ✅ Batch 251 completed successfully
# ✅ Batch 252 completed successfully
# ✅ Batch 253 completed successfully
# ✅ Batch 254 completed successfully
# ✅ Batch 255 completed successfully
# ✅ Batch 256 completed successfully
# ✅ Batch 257 completed successfully
# ✅ Batch 258 completed successfully
# ✅ Batch 259 completed successfully
# ✅ Batch 260 completed successfully
# ✅ Batch 261 completed successfully
# ✅ Batch 262 completed successfully
# ✅ Batch 263 completed successfully
# ✅ Batch 264 completed successfully
# ✅ Batch 265 completed successfully
# ✅ Batch 266 completed successfully
# ✅ Batch 267 completed successfully
# ✅ Batch 268 completed successfully
# ✅ Batch 269 completed successfully
# ✅ Batch 270 completed successfully
# ✅ Batch 271 completed successfully
# ✅ Batch 272 completed successfully
# ✅ Batch 273 completed successfully
# ✅ Batch 274 completed successfully
# ✅ Batch 275 completed successfully
# ✅ Batch 276 completed successfully
# ✅ Batch 277 completed successfully
# ✅ Batch 278 completed successfully
# ✅ Batch 279 completed successfully
# ✅ Batch 280 completed successfully
# ✅ Batch 281 completed successfully
# ✅ Batch 282 completed successfully
# ✅ Batch 283 completed successfully
#
# 📊 PROCESSING SUMMARY:
# Total ingredients: 5641
# Total batches: 283
# Successful batches: 283
# Failed batches: 0
# 💾 Saved 5641 analyses to dietary_analysis_results.json
# Sample: amarante soufflé - Vegan: True
